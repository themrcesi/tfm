# %% [markdown]
# # Instalación de librerías e imports

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (3.0.6)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (0.5.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (1.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (8.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (2.4.1)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied: jinja2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (1.19.2)
# Requirement already satisfied: setuptools in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (52.0.0.post20210125)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (20.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (2.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (2.25.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from pathy>=0.3.5->spacy) (3.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from jinja2->spacy) (1.1.1)

# %%
# !python -m spacy download es_dep_news_trf
# Out:
# Collecting es-dep-news-trf==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_dep_news_trf-3.0.0/es_dep_news_trf-3.0.0-py3-none-any.whl (409.9 MB)
# Requirement already satisfied: spacy-transformers<1.1.0,>=1.0.0rc4 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from es-dep-news-trf==3.0.0) (1.0.2)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from es-dep-news-trf==3.0.0) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (20.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (3.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (8.0.3)
# Requirement already satisfied: setuptools in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (52.0.0.post20210125)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (2.0.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (1.19.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (0.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (0.7.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (2.25.1)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (1.7.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (2.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (2.4.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (0.5.2)
# Requirement already satisfied: jinja2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (4.59.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (1.0.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (3.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (1.26.4)
# Requirement already satisfied: transformers<4.6.0,>=3.4.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (4.4.2)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (0.8.3)
# Requirement already satisfied: torch>=1.5.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (1.6.0)
# Requirement already satisfied: future in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (0.18.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (2021.3.17)
# Requirement already satisfied: filelock in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (3.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (0.10.1)
# Requirement already satisfied: sacremoses in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (0.0.43)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->es-dep-news-trf==3.0.0) (1.1.1)
# Requirement already satisfied: six in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from sacremoses->transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (1.15.0)
# Requirement already satisfied: joblib in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from sacremoses->transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->es-dep-news-trf==3.0.0) (1.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('es_dep_news_trf')

# %%
# !python -m spacy download en_core_web_trf
# Out:
# Collecting en-core-web-trf==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.0.0/en_core_web_trf-3.0.0-py3-none-any.whl (459.7 MB)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from en-core-web-trf==3.0.0) (3.0.6)
# Requirement already satisfied: spacy-transformers<1.1.0,>=1.0.0rc4 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from en-core-web-trf==3.0.0) (1.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (4.59.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.25.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.0.5)
# Requirement already satisfied: setuptools in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (52.0.0.post20210125)
# Requirement already satisfied: packaging>=20.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (20.9)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.3.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (8.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.7.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.19.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.5.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.4.1)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.7.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.8.2)
# Requirement already satisfied: jinja2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.10)
# Requirement already satisfied: torch>=1.5.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.6.0)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.8.3)
# Requirement already satisfied: transformers<4.6.0,>=3.4.0 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (4.4.2)
# Requirement already satisfied: future in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.18.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.10.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (2021.3.17)
# Requirement already satisfied: filelock in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (3.0.12)
# Requirement already satisfied: sacremoses in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.0.43)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.1.1)
# Requirement already satisfied: six in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from sacremoses->transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.15.0)
# Requirement already satisfied: joblib in c:\users\themrcesi\anaconda3\envs\ia\lib\site-packages (from sacremoses->transformers<4.6.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
import json
import numpy as np
import os
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize
from nltk.stem import PorterStemmer
from joblib import Parallel, delayed
from gensim import corpora
from gensim import models
import pandas as pd
from gensim.similarities import MatrixSimilarity, SparseMatrixSimilarity, Similarity
from operator import itemgetter
import glob
from matplotlib import pyplot as plt
import re
from typing import List
import spacy
import pickle

# %%
ENGLISH_DICT = r""
SPANISH_DICT = r""
STOPWORDS_SPANISH = r"../resources/stopwords.txt"

# %% [markdown]
# # Preprocesado

# %% [markdown]
# ## Eliminación de símbolos

# %%
class SymbolRemover():
    
    def __init__(self):
        self.replace_no_space = re.compile("(\&)|(\%)|(\$)|(\€)|(\.)|(\;)|(\:)|(\!)|(\')|(\¿)|(\¡)|(\!)|(\?)|(\,)|(\")|(\()|(\))|(\[)|(\])|(\d+)|(\⁰)|(\•)|(\\')")
        self.replace_space = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)|(\t)|(  )|(\n)")
    
    def execute(self, input_text) -> str:
        """
        Recibe un texto en crudo y elimina los caracteres que no aportan significado.
        Devuelve el texto en formato string en minúsculas.
        """
        returned = self.replace_no_space.sub("", input_text.lower())
        returned = self.replace_space.sub(" ", returned)       
        return returned

# %%
symbolRemover = SymbolRemover()

# %%
symbolRemover.execute("esto ?¿ es una € prub&a")
# Out:
# 'esto es una pruba'

# %% [markdown]
# ## Tokenización

# %%
class Tokenizer():
    
    def __init__(self, component):
        self.component = component
    
    def execute(self, input_text) -> List[str]:
        """
        Recibe un texto y devuelve una lista de tokens.
        """
        output = self.component.execute(input_text)
        return output.split(" ")

# %%
tokenizer = Tokenizer(SymbolRemover())

# %%
tokenizer.execute("esto ?¿ es una € prub&a")
# Out:
# ['esto', 'es', 'una', 'pruba']

# %% [markdown]
# ## Eliminación de palabras vacías

# %%
class StopwordsRemover():
    
    def __init__(self, path, component):
        self.component = component
        self.stopwords = [line.strip() for line in open(path, "r", encoding = "utf-8").readlines()]
        
    def execute(self, input_text) -> List[str]:
        """
        Filtra los tokens eliminando aquellos que son palabras vacías.
        """
        tokens = self.component.execute(input_text)
        return [token for token in tokens if token not in self.stopwords]

# %%
spanishStopwordsRemover = StopwordsRemover(STOPWORDS_SPANISH, Tokenizer(SymbolRemover()))

# %%
spanishStopwordsRemover.execute("esto ?¿ es una € prub&a")
# Out:
# ['pruba']

# %%
englishStopwordsRemover = StopwordsRemover("../resources/english_stopwords.txt", Tokenizer(SymbolRemover()))

# %%
englishStopwordsRemover.execute("this is a test")
# Out:
# ['test']

# %% [markdown]
# ## Lematización

# %%
class LemmatizerTagger():
    
    conversions = {
        "ADJ": "a",
        "ADV": "adv",
        "NOUN": "n",
        "NUM": "n",
        "PRON": "n",
        "PROPN": "n",
        "VERB": "v",
        "ADP": "prep",
        "JJ": "a",
        "JJR": "a",
        "JJS": "a",
        "NN": "n",
        "NNP": "n",
        "NNPS": "n",
        "NNS": "n",
        "RB": "adv",
        "RBR": "adv",
        "RBS": "adv",
        "RP": "adv",
        "VB": "v",
        "VBD": "v",
        "VBG": "v",
        "VBN": "v",
        "VBP": "v",
        "VBZ": "v",
    }
    
    def __init__(self, model, component):
        self.nlp = spacy.load(model)
        self.component = component
        
    def execute(self, input_text) -> List[str]:
        """
        Recibe una lista de tokens y devuelve sus lemas.
        """
        tokens = self.component.execute(input_text)
        returned = []
        for token in self.nlp(" ".join(tokens)):
            try:
                returned.append({
                    "lemma": token.lemma_,
                    "pos": self.conversions[token.tag_]
                })
            except:
                print(f"ERROR: {token} - {token.tag_}")
        return returned

# %%
spanishLemmatizer = LemmatizerTagger("es_dep_news_trf", StopwordsRemover(STOPWORDS_SPANISH, Tokenizer(SymbolRemover())))
englishLemmatizer = LemmatizerTagger("en_core_web_trf", StopwordsRemover("../resources/english_stopwords.txt", Tokenizer(SymbolRemover())))

# %%
spanishLemmatizer.execute("esto ?¿ es una € prueb&a")
# Out:
# [{'lemma': 'prueba', 'pos': 'n'}]

# %%
englishLemmatizer.execute("this is a test, beautiful girls")
# Out:
# [{'lemma': 'test', 'pos': 'v'},
#  {'lemma': 'beautiful', 'pos': 'a'},
#  {'lemma': 'girl', 'pos': 'n'}]

# %% [markdown]
# # Traducción

# %% [markdown]
# ## Creación de los diccionarios

# %% [markdown]
# ### Diccionario Inglés-UNL

# %%
eng_unl = pd.read_csv("../resources/eng-unl.txt", sep = "\t", names = ["lemma", "a", "uw", "ex1", "ex2", "pos", "_"])

# %%
eng_unl = eng_unl[["lemma", "uw", "pos"]]

# %%
eng_unl["lemma"] = eng_unl["lemma"].apply(lambda x: x.strip("\[\]"))

# %%
eng_unl["pos"] = eng_unl["pos"].apply(lambda x: x.strip("{}"))

# %%
eng_unl.head()
# Out:
#            lemma                                         uw pos
# 0   1 chronicles  1_chronicles(iof>sacred_text>information)   n
# 1        1 kings       1_kings(iof>sacred_text>information)   n
# 2       1 samuel      1_samuel(iof>sacred_text>information)   n
# 3       24 hours         24_hours(icl>period>time,icl>unit)   n
# 4  24-karat gold              24-karat_gold(icl>gold>thing)   n

# %%
dic = {}
for _,row in eng_unl.iterrows():
    if row["lemma"] in dic:
        lemma = row["lemma"]
        uw = row["uw"]
        pos = row["pos"]
        entry = {
            "uw": uw,
            "pos": pos
        }
        dic[lemma].append(entry)
    else:
        lemma = row["lemma"]
        uw = row["uw"]
        pos = row["pos"]
        entry = {
            "uw": uw,
            "pos": pos
        }
        dic[lemma] = [entry]

# %%
with open("../resources/eng2unl.pickle", "wb") as f:
    pickle.dump(dic, f)

# %% [markdown]
# ### Diccionario UNL-Español

# %%
esp_unl = pd.read_csv("../resources/esp-unl.txt", sep = "\t", names = ["lemma", "a", "uw", "ex1", "ex2", "pos", "_"])

# %%
esp_unl = esp_unl[["lemma", "uw", "pos"]]

# %%
esp_unl["lemma"] = esp_unl["lemma"].apply(lambda x: x.strip("\[\]"))

# %%
esp_unl["pos"] = esp_unl["pos"].apply(lambda x: x.strip("{}"))

# %%
esp_unl.head()
# Out:
#          lemma                                                 uw pos
# 0  abalanzarse                    brood(icl>hang>occur,obj>thing)   v
# 1  abalanzarse          hover(icl>hang>occur,cob>thing,obj>thing)   v
# 2  abalanzarse           loom(icl>hang>occur,equ>brood,obj>thing)   v
# 3    abandonar        abandon(icl>leave>do,agt>person,obj>person)   v
# 4    abandonar  abandon(icl>leave>do,equ>vacate,agt>thing,obj>...   v

# %%
dic = {}
for _,row in esp_unl.iterrows():
    if row["uw"] in dic:
        lemma = row["lemma"]
        uw = row["uw"]
        pos = row["pos"]
        entry = {
            "lemma": lemma,
            "pos": pos
        }
        dic[uw].append(entry)
    else:
        lemma = row["lemma"]
        uw = row["uw"]
        pos = row["pos"]
        entry = {
            "lemma": lemma,
            "pos": pos
        }
        dic[uw] = [entry]

# %%
dic
# Out:
# {'brood(icl>hang>occur,obj>thing)': [{'lemma': 'abalanzarse', 'pos': 'v'},
#   {'lemma': 'aparecer', 'pos': 'v'}],
#  'hover(icl>hang>occur,cob>thing,obj>thing)': [{'lemma': 'abalanzarse',
#    'pos': 'v'},
#   {'lemma': 'aparecer', 'pos': 'v'}],
#  'loom(icl>hang>occur,equ>brood,obj>thing)': [{'lemma': 'abalanzarse',
#    'pos': 'v'},
#   {'lemma': 'aparecer', 'pos': 'v'}],
#  'abandon(icl>leave>do,agt>person,obj>person)': [{'lemma': 'abandonar',
#    'pos': 'v'}],
#  'abandon(icl>leave>do,equ>vacate,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'desalojar', 'pos': 'v'}],
#  'bequeath(icl>give>do,agt>thing,obj>thing,gol>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'},
#   {'lemma': 'entregar', 'pos': 'v'}],
#  'break_away(icl>separate>occur,equ>break,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'}],
#  'break(icl>interrupt>do,plt>thing,agt>person,obj>abstract_thing)': [{'lemma': 'abandonar',
#    'pos': 'v'}],
#  'defect(icl>flee>do,plf>thing,agt>volitional_thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'}],
#  'depart(icl>change>do,equ>leave,agt>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'},
#   {'lemma': 'irse', 'pos': 'v'},
#   {'lemma': 'largarse', 'pos': 'v'},
#   {'lemma': 'marcharse', 'pos': 'v'}],
#  'desert(icl>flee>do,equ>defect,agt>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'}],
#  'desert(icl>leave>do,equ>abandon,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'}],
#  'desolate(icl>leave>do,equ>abandon,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'}],
#  'drop(icl>discontinue>do,agt>volitional_thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'}],
#  'drop_out(icl>do,agt>volitional_thing,scn>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'arrojar la toalla', 'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'},
#   {'lemma': 'desistir', 'pos': 'v'}],
#  'empty(icl>leave>do,equ>vacate,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'desalojar', 'pos': 'v'}],
#  'forsake(icl>leave>do,equ>abandon,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'}],
#  'jettison(icl>discard>do,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'desechar', 'pos': 'v'}],
#  'leave_behind(icl>do,equ>leave,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'}],
#  'leave(icl>bequeath>do,agt>person,obj>thing,rec>person)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'},
#   {'lemma': 'entregar', 'pos': 'v'}],
#  'leave(icl>change>do,agt>volitional_thing,obj>volitional_thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'},
#   {'lemma': 'irse', 'pos': 'v'},
#   {'lemma': 'largarse', 'pos': 'v'},
#   {'lemma': 'marcharse', 'pos': 'v'}],
#  'quit(icl>do,equ>drop_out,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'arrojar la toalla', 'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'},
#   {'lemma': 'desistir', 'pos': 'v'}],
#  'vacate(icl>leave>do,agt>thing,obj>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'desalojar', 'pos': 'v'}],
#  'will(icl>bequeath>do,agt>volitional_thing,obj>thing,rec>thing)': [{'lemma': 'abandonar',
#    'pos': 'v'},
#   {'lemma': 'dejar', 'pos': 'v'},
#   {'lemma': 'entregar', 'pos': 'v'}],
#  'abandonment(icl>disposal>thing)': [{'lemma': 'abandono', 'pos': 'n'}],
#  'abandonment(icl>rejection>thing)': [{'lemma': 'abandono', 'pos': 'n'}],
#  'abandonment(icl>withdrawal>thing,equ>desertion)': [{'lemma': 'abandono',
#    'pos': 'n'}],
#  'relinquishment(icl>termination>thing)': [{'lemma': 'abandono', 'pos': 'n'}],
#  'slovenliness(icl>uncleanliness>thing)': [{'lemma': 'abandono', 'pos': 'n'},
#   {'lemma': 'dejadez', 'pos': 'n'},
#   {'lemma': 'desaliño', 'pos': 'n'}],
#  'cram(icl>stuff>do,equ>jam,plt>thing,agt>thing,obj>concrete_thing)': [{'lemma': 'abarrotar',
#    'pos': 'v'},
#   {'lemma': 'apiñar', 'pos': 'v'},
#   {'lemma': 'apretar', 'pos': 'v'},
#   {'lemma': 'apretujar', 'pos': 'v'},
#   {'lemma': 'embutir', 'pos': 'v'}],
#  'jampack(icl>stuff>do,equ>jam,agt>thing,obj>concrete_thing,ins>thing)': [{'lemma': 'abarrotar',
#    'pos': 'v'},
#   {'lemma': 'apiñar', 'pos': 'v'},
#   {'lemma': 'apretar', 'pos': 'v'},
#   {'lemma': 'apretujar', 'pos': 'v'},
#   {'lemma': 'embutir', 'pos': 'v'}],
#  'ram(icl>stuff>do,equ>jam,agt>thing,obj>thing)': [{'lemma': 'abarrotar',
#    'pos': 'v'},
#   {'lemma': 'apiñar', 'pos': 'v'},
#   {'lemma': 'apretar', 'pos': 'v'},
#   {'lemma': 'apretujar', 'pos': 'v'},
#   {'lemma': 'embutir', 'pos': 'v'}],
#  'wad(icl>stuff>do,equ>jam,agt>thing,obj>thing)': [{'lemma': 'abarrotar',
#    'pos': 'v'},
#   {'lemma': 'apiñar', 'pos': 'v'},
#   {'lemma': 'apretar', 'pos': 'v'},
#   {'lemma': 'apretujar', 'pos': 'v'},
#   {'lemma': 'embutir', 'pos': 'v'}],
#  'buy_in(icl>buy>do,agt>volitional_thing,obj>concrete_thing,cag>thing)': [{'lemma': 'abastecer',
#    'pos': 'v'}],
#  'issue(icl>do,equ>distribute,plf>thing,agt>thing,obj>thing,rec>thing)': [{'lemma': 'abastecer',
#    'pos': 'v'},
#   {'lemma': 'aprovisionar', 'pos': 'v'},
#   {'lemma': 'proveer', 'pos': 'v'}],
#  'supply(icl>deliver>do,plt>thing,agt>thing,obj>thing)': [{'lemma': 'abastecer',
#    'pos': 'v'},
#   {'lemma': 'aprovisionar', 'pos': 'v'},
#   {'lemma': 'proveer', 'pos': 'v'}],
#  'take_in(icl>receive>do,agt>thing,obj>thing)': [{'lemma': 'abastecer',
#    'pos': 'v'},
#   {'lemma': 'llenar', 'pos': 'v'}],
#  'take_up(icl>receive>do,equ>take_in,agt>thing,obj>thing)': [{'lemma': 'abastecer',
#    'pos': 'v'},
#   {'lemma': 'llenar', 'pos': 'v'}],
#  'provision(icl>action,agt>thing,obj>thing,rec>thing)': [{'lemma': 'abastecimiento',
#    'pos': 'n'},
#   {'lemma': 'abasto', 'pos': 'n'},
#   {'lemma': 'aprovisionamiento', 'pos': 'n'}],
#  'supply(icl>activity>thing,equ>provision)': [{'lemma': 'abastecimiento',
#    'pos': 'n'},
#   {'lemma': 'abasto', 'pos': 'n'},
#   {'lemma': 'aprovisionamiento', 'pos': 'n'}],
#  'commissariat(icl>food>thing)': [{'lemma': 'abasto', 'pos': 'n'},
#   {'lemma': 'bastimento', 'pos': 'n'},
#   {'lemma': 'munición', 'pos': 'n'},
#   {'lemma': 'pertrechos', 'pos': 'n'},
#   {'lemma': 'subsistencia', 'pos': 'n'}],
#  'provender(icl>food>thing,equ>commissariat)': [{'lemma': 'abasto',
#    'pos': 'n'},
#   {'lemma': 'bastimento', 'pos': 'n'},
#   {'lemma': 'munición', 'pos': 'n'},
#   {'lemma': 'pertrechos', 'pos': 'n'},
#   {'lemma': 'subsistencia', 'pos': 'n'}],
#  'cast_down(icl>discourage>do,equ>depress,agt>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'deprimir', 'pos': 'v'},
#   {'lemma': 'desalentar', 'pos': 'v'},
#   {'lemma': 'desanimar', 'pos': 'v'},
#   {'lemma': 'desmoralizar', 'pos': 'v'}],
#  'deject(icl>discourage>do,equ>depress,agt>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'deprimir', 'pos': 'v'},
#   {'lemma': 'desalentar', 'pos': 'v'},
#   {'lemma': 'desanimar', 'pos': 'v'},
#   {'lemma': 'desmoralizar', 'pos': 'v'}],
#  'demoralize(icl>discourage>do,equ>depress,agt>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'deprimir', 'pos': 'v'},
#   {'lemma': 'desalentar', 'pos': 'v'},
#   {'lemma': 'desanimar', 'pos': 'v'},
#   {'lemma': 'desmoralizar', 'pos': 'v'}],
#  'depress(icl>discourage>do,agt>thing,obj>thing,met>thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'deprimir', 'pos': 'v'},
#   {'lemma': 'desalentar', 'pos': 'v'},
#   {'lemma': 'desanimar', 'pos': 'v'},
#   {'lemma': 'desmoralizar', 'pos': 'v'}],
#  'dishearten(icl>discourage>do,agt>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'}],
#  'dismay(icl>discourage>do,equ>depress,agt>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'deprimir', 'pos': 'v'},
#   {'lemma': 'desalentar', 'pos': 'v'},
#   {'lemma': 'desanimar', 'pos': 'v'},
#   {'lemma': 'desmoralizar', 'pos': 'v'}],
#  'dispirit(icl>discourage>do,equ>depress,agt>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'deprimir', 'pos': 'v'},
#   {'lemma': 'desalentar', 'pos': 'v'},
#   {'lemma': 'desanimar', 'pos': 'v'},
#   {'lemma': 'desmoralizar', 'pos': 'v'}],
#  'get_down(icl>discourage>do,equ>depress,agt>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'deprimir', 'pos': 'v'},
#   {'lemma': 'desalentar', 'pos': 'v'},
#   {'lemma': 'desanimar', 'pos': 'v'},
#   {'lemma': 'desmoralizar', 'pos': 'v'}],
#  'put_off(icl>discourage>do,equ>dishearten,agt>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'}],
#  'reduce(icl>do,equ>demote,cob>person,agt>person,obj>person)': [{'lemma': 'abatir',
#    'pos': 'v'}],
#  'topple(icl>descend>occur,equ>tumble,plt>thing,plf>thing,obj>thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'caerse', 'pos': 'v'},
#   {'lemma': 'demoler', 'pos': 'v'},
#   {'lemma': 'derribar', 'pos': 'v'}],
#  'tumble(icl>descend>occur,plt>thing,plf>thing,obj>concrete_thing)': [{'lemma': 'abatir',
#    'pos': 'v'},
#   {'lemma': 'caerse', 'pos': 'v'},
#   {'lemma': 'demoler', 'pos': 'v'},
#   {'lemma': 'derribar', 'pos': 'v'}],
#  'abdomen(icl>body_part>thing)': [{'lemma': 'abdomen', 'pos': 'n'}],
#  'belly(icl>body_part>thing,equ>abdomen)': [{'lemma': 'abdomen', 'pos': 'n'},
#   {'lemma': 'estómago', 'pos': 'n'}],
#  'venter(icl>body_part>thing,equ>abdomen)': [{'lemma': 'abdomen', 'pos': 'n'},
#   {'lemma': 'estómago', 'pos': 'n'}],
#  'press-up(icl>arm_exercise>thing,equ>pushup)': [{'lemma': 'abdominal',
#    'pos': 'n'},
#   {'lemma': 'flexión', 'pos': 'n'}],
#  'pushup(icl>arm_exercise>thing)': [{'lemma': 'abdominal', 'pos': 'n'},
#   {'lemma': 'flexión', 'pos': 'n'}],
#  'sharpie(icl>actor>thing,equ>eager_beaver)': [{'lemma': 'abeja', 'pos': 'n'},
#   {'lemma': 'rayo', 'pos': 'n'}],
#  'aberrant(icl>adj)': [{'lemma': 'aberrante', 'pos': 'a'}],
#  'gap(icl>space>thing,equ>opening)': [{'lemma': 'abertura', 'pos': 'n'}],
#  'opening(icl>artifact>thing)': [{'lemma': 'abertura', 'pos': 'n'}],
#  'opening(icl>introduction>thing)': [{'lemma': 'abertura', 'pos': 'n'}],
#  'opening(icl>space>thing)': [{'lemma': 'abertura', 'pos': 'n'}],
#  'rent(icl>tear>thing)': [{'lemma': 'abertura', 'pos': 'n'},
#   {'lemma': 'hendidura', 'pos': 'n'},
#   {'lemma': 'raja', 'pos': 'n'}],
#  'rip(icl>tear>thing,equ>rent)': [{'lemma': 'abertura', 'pos': 'n'},
#   {'lemma': 'hendidura', 'pos': 'n'},
#   {'lemma': 'raja', 'pos': 'n'}],
#  'split(icl>tear>thing,equ>rent)': [{'lemma': 'abertura', 'pos': 'n'},
#   {'lemma': 'hendidura', 'pos': 'n'},
#   {'lemma': 'raja', 'pos': 'n'}],
#  'assailable(icl>adj)': [{'lemma': 'abierto', 'pos': 'a'},
#   {'lemma': 'indefendible', 'pos': 'a'},
#   {'lemma': 'indefensable', 'pos': 'a'},
#   {'lemma': 'indefensible', 'pos': 'a'}],
#  'forthcoming(icl>adj,equ>extroverted)': [{'lemma': 'abierto', 'pos': 'a'},
#   {'lemma': 'comunicativo', 'pos': 'a'},
#   {'lemma': 'extrovertido', 'pos': 'a'}],
#  'open(icl>adj,equ>assailable)': [{'lemma': 'abierto', 'pos': 'a'},
#   {'lemma': 'indefendible', 'pos': 'a'},
#   {'lemma': 'indefensable', 'pos': 'a'},
#   {'lemma': 'indefensible', 'pos': 'a'}],
#  'open(icl>adj,equ>candid)': [{'lemma': 'abierto', 'pos': 'a'},
#   {'lemma': 'cándido', 'pos': 'a'}],
#  'open(icl>adj,equ>overt,ant>covert)': [{'lemma': 'abierto', 'pos': 'a'}],
#  'overt(icl>adj,ant>covert)': [{'lemma': 'abierto', 'pos': 'a'}],
#  'undecided(icl>adj,equ>open)': [{'lemma': 'abierto', 'pos': 'a'}],
#  'undefended(icl>adj,equ>assailable)': [{'lemma': 'abierto', 'pos': 'a'},
#   {'lemma': 'indefendible', 'pos': 'a'},
#   {'lemma': 'indefensable', 'pos': 'a'},
#   {'lemma': 'indefensible', 'pos': 'a'}],
#  'hell(icl>imaginary_place>thing,equ>hel)': [{'lemma': 'abismo', 'pos': 'n'},
#   {'lemma': 'averno', 'pos': 'n'},
#   {'lemma': 'infierno', 'pos': 'n'},
#   {'lemma': 'orco', 'pos': 'n'}],
#  'underworld(icl>imaginary_place>thing,equ>hel)': [{'lemma': 'abismo',
#    'pos': 'n'},
#   {'lemma': 'averno', 'pos': 'n'},
#   {'lemma': 'infierno', 'pos': 'n'},
#   {'lemma': 'orco', 'pos': 'n'}],
#  'goldbrick(icl>idler>thing)': [{'lemma': 'ablandabrevas', 'pos': 'n'},
#   {'lemma': 'calamidad', 'pos': 'n'},
#   {'lemma': 'cantonero', 'pos': 'n'},
#   {'lemma': 'follón', 'pos': 'n'},
#   {'lemma': 'inútil', 'pos': 'n'},
#   {'lemma': 'mequetrefe', 'pos': 'n'},
#   {'lemma': 'pelafustán', 'pos': 'n'}],
#  'mellow(icl>change>occur,obj>thing)': [{'lemma': 'ablandarse', 'pos': 'v'},
#   {'lemma': 'atemperar', 'pos': 'v'},
#   {'lemma': 'dulcificarse', 'pos': 'v'},
#   {'lemma': 'moderar', 'pos': 'v'}],
#  'mellow(icl>soften>do,agt>thing,obj>thing)': [{'lemma': 'ablandarse',
#    'pos': 'v'},
#   {'lemma': 'envejecer', 'pos': 'v'}],
#  'melt(icl>soften>occur,obj>person)': [{'lemma': 'ablandarse', 'pos': 'v'},
#   {'lemma': 'atemperar', 'pos': 'v'},
#   {'lemma': 'dulcificarse', 'pos': 'v'},
#   {'lemma': 'moderar', 'pos': 'v'}],
#  'weaken(icl>enfeeble>do,agt>thing,obj>thing)': [{'lemma': 'ablandar',
#    'pos': 'v'},
#   {'lemma': 'debilitar', 'pos': 'v'},
#   {'lemma': 'flaquear', 'pos': 'v'}],
#  'abnegation(icl>selflessness>thing)': [{'lemma': 'abnegación', 'pos': 'n'}],
#  'self-abnegation(icl>selflessness>thing,equ>abnegation)': [{'lemma': 'abnegación',
#    'pos': 'n'}],
#  'self-denial(icl>selflessness>thing,equ>abnegation)': [{'lemma': 'abnegación',
#    'pos': 'n'}],
#  'self-renunciation(icl>selflessness>thing,equ>abnegation)': [{'lemma': 'abnegación',
#    'pos': 'n'}],
#  'attaint(icl>do,equ>dishonor,agt>thing,obj>thing)': [{'lemma': 'abochornar',
#    'pos': 'v'},
#   {'lemma': 'avergonzar', 'pos': 'v'}],
#  'disgrace(icl>do,equ>dishonor,agt>thing,obj>thing)': [{'lemma': 'abochornar',
#    'pos': 'v'},
#   {'lemma': 'avergonzar', 'pos': 'v'}],
#  'dishonour(icl>do,equ>dishonor,agt>thing,obj>thing)': [{'lemma': 'abochornar',
#    'pos': 'v'},
#   {'lemma': 'avergonzar', 'pos': 'v'}],
#  'shame(icl>arouse>do,agt>thing,obj>thing)': [{'lemma': 'abochornar',
#    'pos': 'v'},
#   {'lemma': 'avergonzar', 'pos': 'v'}],
#  'shame(icl>compel>do,agt>person,obj>person,gol>thing)': [{'lemma': 'abochornar',
#    'pos': 'v'}],
#  'shame(icl>do,equ>dishonor,agt>thing,obj>person,gol>thing)': [{'lemma': 'abochornar',
#    'pos': 'v'},
#   {'lemma': 'avergonzar', 'pos': 'v'}],
#  'attorney(icl>professional>thing,equ>lawyer)': [{'lemma': 'abogado',
#    'pos': 'n'}],
#  'lawyer(icl>professional>thing)': [{'lemma': 'abogado', 'pos': 'n'}],
#  'defend(icl>fight>do,equ>protect)': [{'lemma': 'abogar', 'pos': 'v'}],
#  'recommend(icl>propose>do,cob>uw,agt>person,obj>uw,rec>person)': [{'lemma': 'abogar',
#    'pos': 'v'},
#   {'lemma': 'preconizar', 'pos': 'v'}],
#  'urge(icl>prompt>do,agt>person,obj>person,pur>uw)': [{'lemma': 'abogar',
#    'pos': 'v'},
#   {'lemma': 'preconizar', 'pos': 'v'}],
#  'filiation(icl>inheritance>thing,equ>ancestry)': [{'lemma': 'abolengo',
#    'pos': 'n'},
#   {'lemma': 'alcurnia', 'pos': 'n'},
#   {'lemma': 'ascendencia', 'pos': 'n'}],
#  'gross(icl>adj,equ>crying)': [{'lemma': 'abominable', 'pos': 'a'},
#   {'lemma': 'atroz', 'pos': 'a'},
#   {'lemma': 'craso', 'pos': 'a'},
#   {'lemma': 'escandaloso', 'pos': 'a'},
#   {'lemma': 'grave', 'pos': 'a'}],
#  'rank(icl>adj,equ>crying)': [{'lemma': 'abominable', 'pos': 'a'},
#   {'lemma': 'atroz', 'pos': 'a'},
#   {'lemma': 'craso', 'pos': 'a'},
#   {'lemma': 'escandaloso', 'pos': 'a'},
#   {'lemma': 'grave', 'pos': 'a'}],
#  'abomination(icl>hate>thing,equ>abhorrence)': [{'lemma': 'abominación',
#    'pos': 'n'}],
#  'detestation(icl>hate>thing,equ>abhorrence)': [{'lemma': 'abominación',
#    'pos': 'n'},
#   {'lemma': 'aborrecimiento', 'pos': 'n'},
#   {'lemma': 'asco', 'pos': 'n'},
#   {'lemma': 'aversión', 'pos': 'n'},
#   {'lemma': 'execración', 'pos': 'n'},
#   {'lemma': 'hastío', 'pos': 'n'},
#   {'lemma': 'horror', 'pos': 'n'}],
#  'execration(icl>hate>thing,equ>abhorrence)': [{'lemma': 'abominación',
#    'pos': 'n'},
#   {'lemma': 'aborrecimiento', 'pos': 'n'},
#   {'lemma': 'asco', 'pos': 'n'},
#   {'lemma': 'aversión', 'pos': 'n'},
#   {'lemma': 'execración', 'pos': 'n'},
#   {'lemma': 'hastío', 'pos': 'n'},
#   {'lemma': 'horror', 'pos': 'n'}],
#  'abhor(icl>hate>do,agt>thing,obj>thing)': [{'lemma': 'abominar', 'pos': 'v'}],
#  'abominate(icl>hate>do,equ>abhor,agt>thing,obj>thing)': [{'lemma': 'abominar',
#    'pos': 'v'}],
#  'execrate(icl>hate>do,equ>abhor,agt>thing,obj>thing)': [{'lemma': 'abominar',
#    'pos': 'v'}],
#  'loathe(icl>hate>do,equ>abhor,agt>thing,obj>thing)': [{'lemma': 'abominar',
#    'pos': 'v'}],
#  'credit(icl>account>do,agt>thing,obj>thing)': [{'lemma': 'abonar',
#    'pos': 'v'}],
#  'credit(icl>impute>do,agt>thing,obj>thing,gol>thing)': [{'lemma': 'abonar',
#    'pos': 'v'}],
#  'fertilize(icl>enrich>do,cob>thing,agt>thing,obj>thing)': [{'lemma': 'abonar',
#    'pos': 'v'}],
#  'manure(icl>spread>do,agt>thing,obj>thing)': [{'lemma': 'abonar',
#    'pos': 'v'}],
#  'muck(icl>spread>do,agt>person)': [{'lemma': 'abonar', 'pos': 'v'}],
#  'pay(icl>give_money>do,cob>thing,rsn>thing,agt>volitional_thing,obj>money,rec>thing)': [{'lemma': 'abonar',
#    'pos': 'v'}],
#  'credit(icl>entry>thing,ant>debit)': [{'lemma': 'abono', 'pos': 'n'},
#   {'lemma': 'asiento de crédito', 'pos': 'n'}],
#  'defrayal(icl>commerce>thing,equ>payment,ant>nonpayment)': [{'lemma': 'abono',
#    'pos': 'n'}],
#  'defrayment(icl>commerce>thing,equ>payment,ant>nonpayment)': [{'lemma': 'abono',
#    'pos': 'n'}],
#  'fertilizer(icl>chemical>thing)': [{'lemma': 'abono', 'pos': 'n'}],
#  'mulch(icl>protective_covering>thing)': [{'lemma': 'abono orgánico',
#    'pos': 'n'}],
#  'deal(icl>relate>be,obj>thing,aoj>thing)': [{'lemma': 'abordar', 'pos': 'v'}],
#  'handle(icl>do,equ>discuss,agt>thing,obj>thing)': [{'lemma': 'abordar',
#    'pos': 'v'}],
#  'tackle(icl>attack>do,agt>thing,obj>thing)': [{'lemma': 'abordar',
#    'pos': 'v'},
#   {'lemma': 'entrar', 'pos': 'v'}],
#  'tackle(icl>face>do,agt>person,obj>uw)': [{'lemma': 'abordar', 'pos': 'v'}],
#  'take_on(icl>confront>do,equ>undertake,agt>thing,obj>thing)': [{'lemma': 'abordar',
#    'pos': 'v'}],
#  'treat(icl>broach>do,equ>cover,agt>thing,obj>thing)': [{'lemma': 'abordar',
#    'pos': 'v'}],
#  'undertake(icl>confront>do,agt>thing,obj>thing)': [{'lemma': 'abordar',
#    'pos': 'v'}],
#  'autochthonal(icl>adj)': [{'lemma': 'aborigen', 'pos': 'a'},
#   {'lemma': 'autóctono', 'pos': 'a'},
#   {'lemma': 'endémico', 'pos': 'a'},
#   {'lemma': 'indígena', 'pos': 'a'},
#   {'lemma': 'nativo', 'pos': 'a'},
#   {'lemma': 'natural', 'pos': 'a'},
#   {'lemma': 'originario', 'pos': 'a'}],
#  'endemic(icl>adj,equ>autochthonal)': [{'lemma': 'aborigen', 'pos': 'a'},
#   {'lemma': 'autóctono', 'pos': 'a'},
#   {'lemma': 'endémico', 'pos': 'a'},
#   {'lemma': 'indígena', 'pos': 'a'},
#   {'lemma': 'nativo', 'pos': 'a'},
#   {'lemma': 'natural', 'pos': 'a'},
#   {'lemma': 'originario', 'pos': 'a'}],
#  'detest(icl>dislike>do,equ>hate,agt>thing,obj>thing)': [{'lemma': 'aborrecer',
#    'pos': 'v'},
#   {'lemma': 'detestar', 'pos': 'v'}],
#  'hate(icl>dislike>be,equ>detest,rsn>uw,obj>uw,aoj>person)': [{'lemma': 'aborrecer',
#    'pos': 'v'},
#   {'lemma': 'detestar', 'pos': 'v'}],
#  'abhorrence(icl>hate>thing)': [{'lemma': 'aborrecimiento', 'pos': 'n'}],
#  'loathing(icl>hate>thing,equ>abhorrence)': [{'lemma': 'aborrecimiento',
#    'pos': 'n'}],
#  'abort(icl>end>do,agt>thing,obj>thing)': [{'lemma': 'abortar', 'pos': 'v'}],
#  'freak(icl>mutant>thing)': [{'lemma': 'aborto', 'pos': 'n'},
#   {'lemma': 'engendro', 'pos': 'n'},
#   {'lemma': 'monstruo', 'pos': 'n'}],
#  'inlet(icl>body_of_water>thing)': [{'lemma': 'abra', 'pos': 'n'},
#   {'lemma': 'bahía', 'pos': 'n'},
#   {'lemma': 'cala', 'pos': 'n'},
#   {'lemma': 'ensenada', 'pos': 'n'},
#   {'lemma': 'rada', 'pos': 'n'}],
#  'recess(icl>body_of_water>thing,equ>inlet)': [{'lemma': 'abra', 'pos': 'n'},
#   {'lemma': 'bahía', 'pos': 'n'},
#   {'lemma': 'cala', 'pos': 'n'},
#   {'lemma': 'ensenada', 'pos': 'n'},
#   {'lemma': 'rada', 'pos': 'n'}],
#  'acid(icl>adj,equ>acerb)': [{'lemma': 'abrasador', 'pos': 'a'},
#   {'lemma': 'ácido', 'pos': 'a'},
#   {'lemma': 'acre', 'pos': 'a'},
#   {'lemma': 'amargo', 'pos': 'a'},
#   {'lemma': 'cáustico', 'pos': 'a'},
#   {'lemma': 'mordaz', 'pos': 'a'},
#   {'lemma': 'virulento', 'pos': 'a'},
#   {'lemma': 'vitriólico', 'pos': 'a'}],
#  'caustic(icl>adj,equ>acerb)': [{'lemma': 'abrasador', 'pos': 'a'},
#   {'lemma': 'ácido', 'pos': 'a'},
#   {'lemma': 'acre', 'pos': 'a'},
#   {'lemma': 'amargo', 'pos': 'a'},
#   {'lemma': 'cáustico', 'pos': 'a'},
#   {'lemma': 'mordaz', 'pos': 'a'},
#   {'lemma': 'virulento', 'pos': 'a'},
#   {'lemma': 'vitriólico', 'pos': 'a'}],
#  'burn(icl>create>do,com>damage,agt>thing,obj>thing)': [{'lemma': 'abrasarse',
#    'pos': 'v'},
#   {'lemma': 'abrasar', 'pos': 'v'},
#   {'lemma': 'quemar', 'pos': 'v'}],
#  'bite(icl>ache>be,obj>animate_thing,aoj>thing)': [{'lemma': 'abrasar',
#    'pos': 'v'}],
#  'burn(icl>shine>be,rsn>thing,aoj>thing)': [{'lemma': 'abrasar', 'pos': 'v'},
#   {'lemma': 'achicharrar', 'pos': 'v'},
#   {'lemma': 'pegar fuerte', 'pos': 'v'}],
#  'burn(icl>sting>do,com>heat,agt>thing,obj>thing)': [{'lemma': 'abrasar',
#    'pos': 'v'}],
#  'combust(icl>do,equ>burn,agt>thing,obj>thing)': [{'lemma': 'abrasar',
#    'pos': 'v'},
#   {'lemma': 'arder', 'pos': 'v'},
#   {'lemma': 'incinerar', 'pos': 'v'},
#   {'lemma': 'quemar', 'pos': 'v'}],
#  'parch(icl>dry>be,obj>thing,aoj>thing)': [{'lemma': 'abrasar', 'pos': 'v'},
#   {'lemma': 'agostarse', 'pos': 'v'},
#   {'lemma': 'chamuscar', 'pos': 'v'},
#   {'lemma': 'marchitar', 'pos': 'v'},
#   {'lemma': 'quemar', 'pos': 'v'}],
#  'sear(icl>dry>be,equ>parch,obj>thing,aoj>thing)': [{'lemma': 'abrasar',
#    'pos': 'v'},
#   {'lemma': 'agostarse', 'pos': 'v'},
#   {'lemma': 'chamuscar', 'pos': 'v'},
#   {'lemma': 'marchitar', 'pos': 'v'},
#   {'lemma': 'quemar', 'pos': 'v'}],
#  'sting(icl>ache>do,equ>bite,agt>thing,obj>thing)': [{'lemma': 'abrasar',
#    'pos': 'v'}],
#  'abrasion(icl>wound>thing)': [{'lemma': 'abrasión', 'pos': 'n'}],
#  'scrape(icl>wound>thing,equ>abrasion)': [{'lemma': 'abrasión', 'pos': 'n'},
#   {'lemma': 'arañazo', 'pos': 'n'},
#   {'lemma': 'rasgadura', 'pos': 'n'},
#   {'lemma': 'rasguño', 'pos': 'n'}],
#  'scratch(icl>wound>thing,equ>abrasion)': [{'lemma': 'abrasión', 'pos': 'n'},
#   {'lemma': 'arañazo', 'pos': 'n'},
#   {'lemma': 'rasgadura', 'pos': 'n'},
#   {'lemma': 'rasguño', 'pos': 'n'}],
#  'clamp(icl>holding_device>thing)': [{'lemma': 'abrazadera', 'pos': 'n'}],
#  'clinch(icl>holding_device>thing,equ>clamp)': [{'lemma': 'abrazadera',
#    'pos': 'n'}],
#  'cuddle(icl>cling_to>do,agt>living_thing,obj>living_thing,plc>thing)': [{'lemma': 'abrazarse',
#    'pos': 'v'}],
#  'nest(icl>cling_to>do,equ>cuddle,agt>thing)': [{'lemma': 'abrazarse',
#    'pos': 'v'}],
#  'nestle(icl>cling_to>do,equ>cuddle,agt>living_thing,obj>living_thing,plc>thing)': [{'lemma': 'abrazarse',
#    'pos': 'v'}],
#  'nuzzle(icl>cling_to>do,equ>cuddle,agt>living_thing,obj>living_thing,plc>thing)': [{'lemma': 'abrazarse',
#    'pos': 'v'}],
#  'snuggle(icl>cling_to>do,equ>cuddle,agt>living_thing,plc>thing)': [{'lemma': 'abrazarse',
#    'pos': 'v'}],
#  'adopt(icl>accept>do,equ>espouse,agt>thing,obj>thing)': [{'lemma': 'abrazar',
#    'pos': 'v'}],
#  'embrace(icl>adopt>do,agt>thing,obj>thing)': [{'lemma': 'abrazar',
#    'pos': 'v'}],
#  'espouse(icl>do,equ>follow,agt>person,obj>uw)': [{'lemma': 'abrazar',
#    'pos': 'v'}],
#  'sweep_up(icl>accept>do,equ>espouse,agt>volitional_thing,obj>thing)': [{'lemma': 'abrazar',
#    'pos': 'v'}],
#  'abbreviate(icl>decrease>do,equ>abridge,agt>thing,obj>thing)': [{'lemma': 'abreviar',
#    'pos': 'v'},
#   {'lemma': 'acortar', 'pos': 'v'},
#   {'lemma': 'contraer', 'pos': 'v'},
#   {'lemma': 'encoger', 'pos': 'v'}],
#  'abridge(icl>decrease>do,agt>thing,obj>thing)': [{'lemma': 'abreviar',
#    'pos': 'v'},
#   {'lemma': 'acortar', 'pos': 'v'},
#   {'lemma': 'contraer', 'pos': 'v'},
#   {'lemma': 'encoger', 'pos': 'v'}],
#  'contract(icl>cause>do,ant>expand,src>uw,agt>thing,obj>concrete_thing,gol>uw,val>thing)': [{'lemma': 'abreviar',
#    'pos': 'v'},
#   {'lemma': 'acortar', 'pos': 'v'},
#   {'lemma': 'contraer', 'pos': 'v'},
#   {'lemma': 'encoger', 'pos': 'v'}],
#  'foreshorten(icl>decrease>do,equ>abridge,agt>volitional_thing,obj>thing)': [{'lemma': 'abreviar',
#    'pos': 'v'},
#   {'lemma': 'acortar', 'pos': 'v'},
#   {'lemma': 'contraer', 'pos': 'v'},
#   {'lemma': 'encoger', 'pos': 'v'}],
#  'reduce(icl>decrease>do,equ>abridge,agt>thing,obj>thing)': [{'lemma': 'abreviar',
#    'pos': 'v'},
#   {'lemma': 'acortar', 'pos': 'v'},
#   {'lemma': 'contraer', 'pos': 'v'},
#   {'lemma': 'encoger', 'pos': 'v'}],
#  'shorten(icl>decrease>do,equ>abridge,agt>thing,obj>thing)': [{'lemma': 'abreviar',
#    'pos': 'v'},
#   {'lemma': 'acortar', 'pos': 'v'},
#   {'lemma': 'contraer', 'pos': 'v'},
#   {'lemma': 'encoger', 'pos': 'v'}],
#  'shorten(icl>reduce>do,agt>thing,obj>thing)': [{'lemma': 'abreviar',
#    'pos': 'v'},
#   {'lemma': 'acortar', 'pos': 'v'}],
#  'entertain(icl>feel>do,equ>harbor,agt>thing,obj>thing)': [{'lemma': 'abrigar',
#    'pos': 'v'}],
#  'harbour(icl>feel>do,equ>harbor,agt>thing,obj>thing)': [{'lemma': 'abrigar',
#    'pos': 'v'}],
#  'nurse(icl>feel>do,equ>harbor,agt>thing,obj>thing)': [{'lemma': 'abrigar',
#    'pos': 'v'}],
#  'shelter(icl>supply>be,cob>thing,obj>thing,aoj>thing)': [{'lemma': 'abrigar',
#    'pos': 'v'},
#   {'lemma': 'amparar', 'pos': 'v'},
#   {'lemma': 'esconder', 'pos': 'v'}],
#  'shelter(icl>protective_covering>thing)': [{'lemma': 'abrigo', 'pos': 'n'},
#   {'lemma': 'amparo', 'pos': 'n'},
#   {'lemma': 'asilo', 'pos': 'n'},
#   {'lemma': 'protección', 'pos': 'n'},
#   {'lemma': 'refugio', 'pos': 'n'}],
#  'shelter(icl>structure>thing)': [{'lemma': 'abrigo', 'pos': 'n'}],
#  'brighten(icl>change>do,agt>thing,obj>concrete_thing,ins>thing)': [{'lemma': 'abrillantar',
#    'pos': 'v'},
#   {'lemma': 'avivar', 'pos': 'v'},
#   {'lemma': 'clarear', 'pos': 'v'}],
#  'lighten(icl>change>do,equ>brighten,agt>thing,obj>concrete_thing,gol>thing,ins>thing)': [{'lemma': 'abrillantar',
#    'pos': 'v'},
#   {'lemma': 'avivar', 'pos': 'v'},
#   {'lemma': 'clarear', 'pos': 'v'}],
#  'blossom(icl>develop>occur,obj>thing)': [{'lemma': 'abrirse', 'pos': 'v'}],
#  'blossom_out(icl>develop>occur,equ>blossom,obj>thing)': [{'lemma': 'abrirse',
#    'pos': 'v'}],
#  'unfold(icl>develop>occur,equ>blossom,obj>thing)': [{'lemma': 'abrirse',
#    'pos': 'v'}],
#  'brighten(icl>occur,equ>clear_up,obj>thing)': [{'lemma': 'abrir', 'pos': 'v'},
#   {'lemma': 'aclararse', 'pos': 'v'},
#   {'lemma': 'aclarar', 'pos': 'v'},
#   {'lemma': 'despejarse', 'pos': 'v'},
#   {'lemma': 'despejar', 'pos': 'v'},
#   {'lemma': 'mejorar', 'pos': 'v'}],
#  'clear(icl>brighten>occur,plf>thing,obj>space>thing,ins>thing)': [{'lemma': 'abrir',
#    'pos': 'v'},
#   {'lemma': 'aclararse', 'pos': 'v'},
#   {'lemma': 'aclarar', 'pos': 'v'},
#   {'lemma': 'despejarse', 'pos': 'v'},
#   {'lemma': 'despejar', 'pos': 'v'},
#   {'lemma': 'mejorar', 'pos': 'v'}],
#  'clear_up(icl>occur,obj>thing)': [{'lemma': 'abrir', 'pos': 'v'},
#   {'lemma': 'aclararse', 'pos': 'v'},
#   {'lemma': 'aclarar', 'pos': 'v'},
#   {'lemma': 'despejarse', 'pos': 'v'},
#   {'lemma': 'despejar', 'pos': 'v'},
#   {'lemma': 'mejorar', 'pos': 'v'}],
#  'light_up(icl>occur,equ>clear_up,obj>thing)': [{'lemma': 'abrir', 'pos': 'v'},
#   {'lemma': 'aclararse', 'pos': 'v'},
#   {'lemma': 'aclarar', 'pos': 'v'},
#   {'lemma': 'despejarse', 'pos': 'v'},
#   {'lemma': 'despejar', 'pos': 'v'},
#   {'lemma': 'mejorar', 'pos': 'v'}],
#  'open(icl>be,equ>open_up,obj>abstract_thing,aoj>thing)': [{'lemma': 'abrir',
#    'pos': 'v'},
#   {'lemma': 'desarrollar', 'pos': 'v'}],
#  'open(icl>undo>do,equ>unfold,agt>thing,obj>thing)': [{'lemma': 'abrir',
#    'pos': 'v'},
#   {'lemma': 'desdoblar', 'pos': 'v'},
#   {'lemma': 'desplegar', 'pos': 'v'}],
#  'open_up(icl>occur,equ>open,obj>thing)': [{'lemma': 'abrir', 'pos': 'v'}],
#  'open_up(icl>yield>do,equ>open,agt>thing,obj>thing)': [{'lemma': 'abrir',
#    'pos': 'v'},
#   {'lemma': 'desarrollar', 'pos': 'v'}],
#  'spread(icl>do,equ>unfold,agt>thing,obj>concrete_thing)': [{'lemma': 'abrir',
#    'pos': 'v'},
#   {'lemma': 'desdoblar', 'pos': 'v'},
#   {'lemma': 'desplegar', 'pos': 'v'}],
#  'spread_out(icl>undo>do,equ>unfold,agt>thing,obj>thing)': [{'lemma': 'abrir',
#    'pos': 'v'},
#   {'lemma': 'desdoblar', 'pos': 'v'},
#   {'lemma': 'desplegar', 'pos': 'v'}],
#  'unfold(icl>undo>do,agt>thing,obj>thing)': [{'lemma': 'abrir', 'pos': 'v'},
#   {'lemma': 'desdoblar', 'pos': 'v'},
#   {'lemma': 'desplegar', 'pos': 'v'}],
#  'unlock(icl>disengage>occur,obj>thing)': [{'lemma': 'abrir', 'pos': 'v'}],
#  'crush(icl>do,equ>oppress,agt>volitional_thing,obj>thing,met>thing)': [{'lemma': 'abrumar',
#    'pos': 'v'},
#   {'lemma': 'oprimir', 'pos': 'v'}],
#  'heap(icl>give>do,cob>thing,agt>thing,obj>thing)': [{'lemma': 'abrumar',
#    'pos': 'v'}],
#  'oppress(icl>do,agt>thing,obj>thing)': [{'lemma': 'abrumar', 'pos': 'v'},
#   {'lemma': 'oprimir', 'pos': 'v'}],
#  'suppress(icl>do,equ>oppress,agt>thing,obj>thing)': [{'lemma': 'abrumar',
#    'pos': 'v'},
#   {'lemma': 'oprimir', 'pos': 'v'}],
#  'abrupt(icl>adj)': [{'lemma': 'abrupto', 'pos': 'a'}],
#  'abscission(icl>removal>thing)': [{'lemma': 'abscisión', 'pos': 'n'}],
#  'absolutism(icl>autocracy>thing,equ>dictatorship)': [{'lemma': 'absolutismo',
#    'pos': 'n'}],
#  'authoritarianism(icl>autocracy>thing,equ>dictatorship)': [{'lemma': 'absolutismo',
#    'pos': 'n'},
#   {'lemma': 'autoritarismo', 'pos': 'n'},
#   {'lemma': 'despotismo', 'pos': 'n'},
#   {'lemma': 'dictadura', 'pos': 'n'},
#   {'lemma': 'tiranía', 'pos': 'n'}],
#  'monocracy(icl>autocracy>thing,equ>dictatorship)': [{'lemma': 'absolutismo',
#    'pos': 'n'},
#   {'lemma': 'autoritarismo', 'pos': 'n'},
#   {'lemma': 'despotismo', 'pos': 'n'},
#   {'lemma': 'dictadura', 'pos': 'n'},
#   {'lemma': 'tiranía', 'pos': 'n'}],
#  'stalinism(icl>autocracy>thing,equ>dictatorship)': [{'lemma': 'absolutismo',
#    'pos': 'n'},
#   {'lemma': 'autoritarismo', 'pos': 'n'},
#   {'lemma': 'despotismo', 'pos': 'n'},
#   {'lemma': 'dictadura', 'pos': 'n'},
#   {'lemma': 'tiranía', 'pos': 'n'}],
#  'absolute(icl>adj,ant>relative)': [{'lemma': 'absoluto', 'pos': 'a'},
#   {'lemma': 'completo', 'pos': 'a'},
#   {'lemma': 'incondicionado', 'pos': 'a'},
#   {'lemma': 'perfecto', 'pos': 'a'},
#   {'lemma': 'total', 'pos': 'a'}],
#  'absolute(icl>adj)': [{'lemma': 'absoluto', 'pos': 'a'},
#   {'lemma': 'incondicionado', 'pos': 'a'}],
#  'outright(icl>absolute,icl>adj)': [{'lemma': 'absoluto', 'pos': 'a'},
#   {'lemma': 'inapelable', 'pos': 'a'},
#   {'lemma': 'incuestionable', 'pos': 'a'},
#   {'lemma': 'indiscutible', 'pos': 'a'},
#   {'lemma': 'rotundo', 'pos': 'a'}],
#  'total(icl>adj,equ>full)': [{'lemma': 'absoluto', 'pos': 'a'},
#   {'lemma': 'completo', 'pos': 'a'},
#   {'lemma': 'perfecto', 'pos': 'a'}],
#  'whole-souled(icl>adj,equ>heart-whole)': [{'lemma': 'absoluto', 'pos': 'a'},
#   {'lemma': 'incondicional', 'pos': 'a'}],
#  'throw_out(icl>do,equ>dismiss,agt>thing,obj>thing)': [{'lemma': 'absolver',
#    'pos': 'v'}],
#  'douse(icl>wet>do,equ>drench,agt>thing,obj>thing)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'empapar', 'pos': 'v'},
#   {'lemma': 'lavar', 'pos': 'v'},
#   {'lemma': 'mojar', 'pos': 'v'}],
#  'dowse(icl>wet>do,equ>drench,agt>thing,obj>thing)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'empapar', 'pos': 'v'},
#   {'lemma': 'lavar', 'pos': 'v'},
#   {'lemma': 'mojar', 'pos': 'v'}],
#  'drench(icl>wet>do,cob>matter,agt>thing,obj>concrete_thing)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'empapar', 'pos': 'v'},
#   {'lemma': 'lavar', 'pos': 'v'},
#   {'lemma': 'mojar', 'pos': 'v'}],
#  'engage(icl>interest>do,equ>absorb,cob>thing,agt>thing,obj>thing)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'atraer', 'pos': 'v'}],
#  'engross(icl>interest>do,equ>absorb,agt>thing,obj>thing)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'atraer', 'pos': 'v'}],
#  'occupy(icl>interest>do,equ>absorb,agt>thing,obj>thing)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'atraer', 'pos': 'v'}],
#  'soak(icl>moisten>do,com>liquid,agt>thing,obj>thing,ins>matter)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'empapar', 'pos': 'v'},
#   {'lemma': 'lavar', 'pos': 'v'},
#   {'lemma': 'mojar', 'pos': 'v'}],
#  'sop(icl>wet>do,equ>drench,agt>thing,obj>thing)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'empapar', 'pos': 'v'},
#   {'lemma': 'lavar', 'pos': 'v'},
#   {'lemma': 'mojar', 'pos': 'v'}],
#  'souse(icl>wet>do,equ>drench,cob>thing,agt>thing,obj>concrete_thing)': [{'lemma': 'absorber',
#    'pos': 'v'},
#   {'lemma': 'empapar', 'pos': 'v'},
#   {'lemma': 'lavar', 'pos': 'v'},
#   {'lemma': 'mojar', 'pos': 'v'}],
#  'absorption(icl>organic_process>thing,equ>assimilation)': [{'lemma': 'absorción',
#    'pos': 'n'}],
#  'abstention(icl>self-discipline>thing,equ>abstinence)': [{'lemma': 'abstención',
#    'pos': 'n'}],
#  'abstain(icl>do,agt>thing)': [{'lemma': 'abstenerse', 'pos': 'v'}],
#  'desist(icl>do,equ>abstain,agt>volitional_thing,obj>thing)': [{'lemma': 'abstenerse',
#    'pos': 'v'}],
#  'refrain(icl>be,equ>abstain,obj>thing,aoj>person)': [{'lemma': 'abstenerse',
#    'pos': 'v'}],
#  'abstinence(icl>self-discipline>thing)': [{'lemma': 'abstinencia',
#    'pos': 'n'}],
#  'abstraction(icl>painting>thing)': [{'lemma': 'abstracción', 'pos': 'n'}],
#  'abstraction(icl>theorization>thing)': [{'lemma': 'abstracción', 'pos': 'n'}],
#  'absurd(icl>adj)': [{'lemma': 'absurdo', 'pos': 'a'}],
#  'ludicrous(icl>adj,equ>absurd)': [{'lemma': 'absurdo', 'pos': 'a'}],
#  'ludicrous(icl>adj,equ>farcical)': [{'lemma': 'absurdo', 'pos': 'a'}],
#  'preposterous(icl>adj,equ>absurd)': [{'lemma': 'absurdo', 'pos': 'a'}],
#  'barracking(icl>break>thing,equ>heckling)': [{'lemma': 'abucheo',
#    'pos': 'n'}],
#  'beldame(icl>old_woman>thing,equ>beldam)': [{'lemma': 'abuela', 'pos': 'n'}],
#  'grandmother(icl>grandparent>thing,equ>grandma,obj>woman,cob>person)': [{'lemma': 'abuela',
#    'pos': 'n'}],
#  'granny(icl>grandparent>thing,equ>grandma)': [{'lemma': 'abuela',
#    'pos': 'n'}],
#  'gramps(icl>grandparent>thing,equ>grandfather)': [{'lemma': 'abuelito',
#    'pos': 'n'},
#   {'lemma': 'abuelo', 'pos': 'n'}],
#  'grandfather(icl>grandparent>thing,obj>man,cob>person)': [{'lemma': 'abuelito',
#    'pos': 'n'},
#   {'lemma': 'abuelo', 'pos': 'n'}],
#  'grandpa(icl>grandparent>thing,equ>grandfather)': [{'lemma': 'abuelo',
#    'pos': 'n'}],
#  'graybeard(icl>oldster>thing,equ>old_man)': [{'lemma': 'abuelo', 'pos': 'n'},
#   {'lemma': 'anciano', 'pos': 'n'}],
#  'methuselah(icl>oldster>thing,equ>old_man)': [{'lemma': 'abuelo', 'pos': 'n'},
#   {'lemma': 'anciano', 'pos': 'n'}],
#  'swell(icl>grow>be,obj>thing,aoj>thing)': [{'lemma': 'abultar', 'pos': 'v'}],
#  'abundance(icl>quantity>thing,ant>scarcity)': [{'lemma': 'abundancia',
#    'pos': 'n'}],
#  'abundant(icl>adj,ant>scarce)': [{'lemma': 'abundante', 'pos': 'a'}],
#  'lush(icl>adj,equ>exuberant)': [{'lemma': 'abundante', 'pos': 'a'},
#   {'lemma': 'abundoso', 'pos': 'a'},
#   {'lemma': 'copioso', 'pos': 'a'},
#   {'lemma': 'exuberante', 'pos': 'a'},
#   {'lemma': 'nombroso', 'pos': 'a'}],
#  'plenteous(icl>adj,equ>ample)': [{'lemma': 'abundante', 'pos': 'a'}],
#  'plentiful(icl>adj,equ>ample)': [{'lemma': 'abundante', 'pos': 'a'}],
#  'plentiful(icl>adj,equ>bountiful)': [{'lemma': 'abundante', 'pos': 'a'}],
#  'profuse(icl>adj,equ>exuberant)': [{'lemma': 'abundante', 'pos': 'a'},
#   {'lemma': 'abundoso', 'pos': 'a'},
#   {'lemma': 'copioso', 'pos': 'a'},
#   {'lemma': 'exuberante', 'pos': 'a'},
#   {'lemma': 'nombroso', 'pos': 'a'}],
#  'solid(icl>adj,equ>hearty)': [{'lemma': 'abundante', 'pos': 'a'},
#   {'lemma': 'bueno', 'pos': 'a'},
#   {'lemma': 'nutritivo', 'pos': 'a'},
#   {'lemma': 'sustancioso', 'pos': 'a'}],
#  'square(icl>adj,equ>hearty)': [{'lemma': 'abundante', 'pos': 'a'},
#   {'lemma': 'bueno', 'pos': 'a'},
#   {'lemma': 'nutritivo', 'pos': 'a'},
#   {'lemma': 'sustancioso', 'pos': 'a'}],
#  'boring(icl>adj)': [{'lemma': 'aburrido', 'pos': 'a'}],
#  'commonplace(icl>adj)': [{'lemma': 'aburrido', 'pos': 'a'},
#   {'lemma': 'ordinario', 'pos': 'a'}],
#  'dull(icl>adj,equ>boring)': [{'lemma': 'aburrido', 'pos': 'a'},
#   {'lemma': 'agobiante', 'pos': 'a'},
#   {'lemma': 'cargante', 'pos': 'a'},
#   {'lemma': 'gris', 'pos': 'a'},
#   {'lemma': 'latoso', 'pos': 'a'},
#   {'lemma': 'monótono', 'pos': 'a'},
#   {'lemma': 'pesado', 'pos': 'a'}],
#  'humdrum(icl>adj,equ>commonplace)': [{'lemma': 'aburrido', 'pos': 'a'},
#   {'lemma': 'ordinario', 'pos': 'a'}],
#  'irksome(icl>adj,equ>boring)': [{'lemma': 'aburrido', 'pos': 'a'},
#   {'lemma': 'agobiante', 'pos': 'a'},
#   {'lemma': 'cargante', 'pos': 'a'},
#   {'lemma': 'gris', 'pos': 'a'},
#   {'lemma': 'latoso', 'pos': 'a'},
#   {'lemma': 'monótono', 'pos': 'a'},
#   {'lemma': 'pesado', 'pos': 'a'}],
#  'slow(icl>adj,equ>boring)': [{'lemma': 'aburrido', 'pos': 'a'},
#   {'lemma': 'agobiante', 'pos': 'a'},
#   {'lemma': 'cargante', 'pos': 'a'},
#   {'lemma': 'gris', 'pos': 'a'},
#   {'lemma': 'latoso', 'pos': 'a'},
#   {'lemma': 'monótono', 'pos': 'a'},
#   {'lemma': 'pesado', 'pos': 'a'}],
#  'tedious(icl>adj,equ>boring)': [{'lemma': 'aburrido', 'pos': 'a'}],
#  'fatigue(icl>devolve>occur,equ>tire,obj>thing)': [{'lemma': 'aburrirse',
#    'pos': 'v'},
#   {'lemma': 'cansarse', 'pos': 'v'},
#   {'lemma': 'fatigarse', 'pos': 'v'}],
#  'jade(icl>devolve>occur,equ>tire,obj>thing)': [{'lemma': 'aburrirse',
#    'pos': 'v'},
#   {'lemma': 'cansarse', 'pos': 'v'},
#   {'lemma': 'fatigarse', 'pos': 'v'}],
#  'pall(icl>devolve>occur,equ>tire,obj>thing)': [{'lemma': 'aburrirse',
#    'pos': 'v'},
#   {'lemma': 'cansarse', 'pos': 'v'},
#   {'lemma': 'fatigarse', 'pos': 'v'}],
#  'bore(icl>do,agt>volitional_thing,obj>volitional_thing,met>thing)': [{'lemma': 'aburrir',
#    'pos': 'v'},
#   {'lemma': 'cansar', 'pos': 'v'},
#   {'lemma': 'fatigar', 'pos': 'v'}],
#  'abuse(icl>treat>do,equ>mistreat,agt>person,obj>living_thing)': [{'lemma': 'abusar',
#    'pos': 'v'},
#   {'lemma': 'malparar', 'pos': 'v'}],
#  'ill-treat(icl>treat>do,equ>mistreat,agt>thing,obj>thing)': [{'lemma': 'abusar',
#    'pos': 'v'},
#   {'lemma': 'malparar', 'pos': 'v'}],
#  'maltreat(icl>treat>do,equ>mistreat,agt>thing,obj>thing)': [{'lemma': 'abusar',
#    'pos': 'v'},
#   {'lemma': 'malparar', 'pos': 'v'}],
#  'mistreat(icl>treat>do,agt>thing,obj>thing)': [{'lemma': 'abusar',
#    'pos': 'v'},
#   {'lemma': 'malparar', 'pos': 'v'}],
#  'step(icl>treat>do,equ>mistreat,agt>thing,obj>thing)': [{'lemma': 'abusar',
#    'pos': 'v'},
#   {'lemma': 'malparar', 'pos': 'v'}],
#  'abuse(icl>use>abstract_thing,obj>thing)': [{'lemma': 'abuso', 'pos': 'n'}],
#  'excess(icl>indulgence>thing,equ>overindulgence)': [{'lemma': 'abuso',
#    'pos': 'n'}],
#  'misuse(icl>use>thing)': [{'lemma': 'abuso', 'pos': 'n'}],
#  'overindulgence(icl>indulgence>thing)': [{'lemma': 'abuso', 'pos': 'n'}],
#  'abjection(icl>humiliation>thing,equ>abasement)': [{'lemma': 'abyección',
#    'pos': 'n'}],
#  'low(icl>adj,equ>abject)': [{'lemma': 'abyecto', 'pos': 'a'},
#   {'lemma': 'bajo', 'pos': 'a'},
#   {'lemma': 'despreciable', 'pos': 'a'},
#   {'lemma': 'miserable', 'pos': 'a'}],
#  'scummy(icl>adj,equ>abject)': [{'lemma': 'abyecto', 'pos': 'a'},
#   {'lemma': 'bajo', 'pos': 'a'},
#   {'lemma': 'despreciable', 'pos': 'a'},
#   {'lemma': 'miserable', 'pos': 'a'}],
#  'scurvy(icl>adj,equ>abject)': [{'lemma': 'abyecto', 'pos': 'a'},
#   {'lemma': 'bajo', 'pos': 'a'},
#   {'lemma': 'despreciable', 'pos': 'a'},
#   {'lemma': 'miserable', 'pos': 'a'}],
#  'finish(icl>decorativeness>thing,equ>coating)': [{'lemma': 'acabado',
#    'pos': 'n'},
#   {'lemma': 'remate', 'pos': 'n'}],
#  'end(icl>boundary>abstract_thing,aoj>concrete_thing)': [{'lemma': 'acabamiento',
#    'pos': 'n'},
#   {'lemma': 'extremo', 'pos': 'n'}],
#  'clear_up(icl>complete>do,equ>get_through,agt>thing,obj>thing)': [{'lemma': 'acabar con',
#    'pos': 'v'}],
#  'finish(icl>cause>do,equ>end,cob>person,agt>thing,obj>person)': [{'lemma': 'acabar con',
#    'pos': 'v'},
#   {'lemma': 'cortar con', 'pos': 'v'}],
#  'finish_off(icl>complete>do,equ>get_through,agt>volitional_thing,obj>thing,met>thing)': [{'lemma': 'acabar con',
#    'pos': 'v'}],
#  'finish_up(icl>complete>do,equ>get_through,agt>thing,obj>thing)': [{'lemma': 'acabar con',
#    'pos': 'v'}],
#  'get_through(icl>complete>do,agt>volitional_thing,obj>thing)': [{'lemma': 'acabar con',
#    'pos': 'v'}],
#  'polish_off(icl>finish>do,agt>volitional_thing,obj>thing,met>thing)': [{'lemma': 'acabar con',
#    'pos': 'v'}],
#  'rack_up(icl>beat>do,equ>worst,agt>thing,obj>thing)': [{'lemma': 'acabar con',
#    'pos': 'v'},
#   {'lemma': 'arrasar', 'pos': 'v'},
#   {'lemma': 'despepitar', 'pos': 'v'}],
#  'whip(icl>beat>do,equ>worst,agt>thing,obj>thing)': [{'lemma': 'acabar con',
#    'pos': 'v'},
#   {'lemma': 'arrasar', 'pos': 'v'},
#   {'lemma': 'despepitar', 'pos': 'v'}],
#  'wrap_up(icl>complete>do,equ>get_through,agt>thing,obj>thing)': [{'lemma': 'acabar con',
#    'pos': 'v'}],
#  'cease(icl>stop>occur,obj>event)': [{'lemma': 'acabar', 'pos': 'v'},
#   {'lemma': 'cesar', 'pos': 'v'},
#   {'lemma': 'concluir', 'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'},
#   {'lemma': 'parar', 'pos': 'v'},
#   {'lemma': 'terminar', 'pos': 'v'}],
#  'end(icl>be,equ>stop,aoj>thing,plc>concrete_thing)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'cesar', 'pos': 'v'},
#   {'lemma': 'concluir', 'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'},
#   {'lemma': 'parar', 'pos': 'v'},
#   {'lemma': 'terminar', 'pos': 'v'}],
#  'end_up(icl>become>occur,obj>thing,gol>thing)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'}],
#  'fetch_up(icl>act>do,equ>finish_up,agt>thing,obj>thing)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'}],
#  'finish(icl>act>do,equ>land_up,agt>person,gol>thing)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'}],
#  'finish(icl>occur,equ>end,obj>thing,gol>uw)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'cesar', 'pos': 'v'},
#   {'lemma': 'concluir', 'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'},
#   {'lemma': 'parar', 'pos': 'v'},
#   {'lemma': 'terminar', 'pos': 'v'}],
#  'finish_up(icl>act>do,agt>thing,obj>thing)': [{'lemma': 'acabar', 'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'}],
#  'land_up(icl>act>do,equ>finish_up,agt>thing,obj>thing)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'}],
#  'stop(icl>occur,ant>continue,obj>thing)': [{'lemma': 'acabar', 'pos': 'v'},
#   {'lemma': 'cesar', 'pos': 'v'},
#   {'lemma': 'concluir', 'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'},
#   {'lemma': 'parar', 'pos': 'v'},
#   {'lemma': 'terminar', 'pos': 'v'}],
#  'terminate(icl>end>do,agt>thing,obj>thing,met>thing)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'concluir', 'pos': 'v'}],
#  'terminate(icl>end>occur,obj>thing,gol>thing)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'cesar', 'pos': 'v'},
#   {'lemma': 'concluir', 'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'},
#   {'lemma': 'parar', 'pos': 'v'},
#   {'lemma': 'terminar', 'pos': 'v'}],
#  'wind_up(icl>bring_to_an_end>do,agt>person,obj>thing)': [{'lemma': 'acabar',
#    'pos': 'v'},
#   {'lemma': 'finalizar', 'pos': 'v'}],
#  'academic(icl>educator>thing,equ>academician)': [{'lemma': 'académica',
#    'pos': 'n'},
#   {'lemma': 'académico', 'pos': 'n'},
#   {'lemma': 'docente', 'pos': 'n'},
#   {'lemma': 'lectora', 'pos': 'n'},
#   {'lemma': 'lector', 'pos': 'n'},
#   {'lemma': 'profesor', 'pos': 'n'}],
#  'academician(icl>educator>thing)': [{'lemma': 'académico', 'pos': 'n'}],
#  'come_about(icl>occur,equ>happen,obj>uw)': [{'lemma': 'acaecer', 'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'},
#   {'lemma': 'suceder', 'pos': 'v'}],
#  'fall_out(icl>occur,equ>happen,obj>thing)': [{'lemma': 'acaecer', 'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'},
#   {'lemma': 'suceder', 'pos': 'v'}],
#  'go_on(icl>occur,equ>happen,obj>thing)': [{'lemma': 'acaecer', 'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'},
#   {'lemma': 'suceder', 'pos': 'v'}],
#  'hap(icl>occur,equ>happen,obj>uw,ben>thing)': [{'lemma': 'acaecer',
#    'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'},
#   {'lemma': 'suceder', 'pos': 'v'}],
#  'happen(icl>be,obj>uw,aoj>thing)': [{'lemma': 'acaecer', 'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'},
#   {'lemma': 'suceder', 'pos': 'v'}],
#  'happen(icl>occur,equ>turn_out,obj>uw)': [{'lemma': 'acaecer', 'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'}],
#  'materialize(icl>happen>occur,equ>happen,obj>thing)': [{'lemma': 'acaecer',
#    'pos': 'v'},
#   {'lemma': 'materializarse', 'pos': 'v'},
#   {'lemma': 'realizarse', 'pos': 'v'}],
#  'occur(icl>appear>occur,obj>thing)': [{'lemma': 'acaecer', 'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'}],
#  'occur(icl>happen>occur,cob>thing,obj>uw,plc>uw)': [{'lemma': 'acaecer',
#    'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'},
#   {'lemma': 'suceder', 'pos': 'v'}],
#  'pass(icl>happen>occur,obj>abstract_thing)': [{'lemma': 'acaecer',
#    'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'},
#   {'lemma': 'suceder', 'pos': 'v'}],
#  'pass_off(icl>occur,equ>happen,obj>thing)': [{'lemma': 'acaecer', 'pos': 'v'},
#   {'lemma': 'ocurrir', 'pos': 'v'},
#   {'lemma': 'pasar', 'pos': 'v'},
#   {'lemma': 'suceder', 'pos': 'v'}],
#  'fervid(icl>adj,equ>ardent)': [{'lemma': 'acalorado', 'pos': 'a'},
#   {'lemma': 'apasionado', 'pos': 'a'},
#   {'lemma': 'ardiente', 'pos': 'a'}],
#  'impassioned(icl>adj,equ>ardent)': [{'lemma': 'acalorado', 'pos': 'a'},
#   {'lemma': 'apasionado', 'pos': 'a'},
#   {'lemma': 'ardiente', 'pos': 'a'}],
#  'heat(icl>emotionality>thing)': [{'lemma': 'acaloramiento', 'pos': 'n'},
#   {'lemma': 'apasionamiento', 'pos': 'n'},
#   {'lemma': 'ardor', 'pos': 'n'},
#   {'lemma': 'exaltación', 'pos': 'n'},
#   {'lemma': 'fervor', 'pos': 'n'},
#   {'lemma': 'pasión', 'pos': 'n'}],
#  'heat(icl>change>occur,obj>thing)': [{'lemma': 'acalorarse', 'pos': 'v'},
#   {'lemma': 'caldear', 'pos': 'v'}],
#  'heat_up(icl>change>occur,obj>thing)': [{'lemma': 'acalorarse', 'pos': 'v'},
#   {'lemma': 'caldear', 'pos': 'v'}],
#  'bivouac(icl>military_quarters>thing,equ>camp)': [{'lemma': 'acantonamiento',
#    'pos': 'n'},
#   {'lemma': 'cantón', 'pos': 'n'},
#   {'lemma': 'vivac', 'pos': 'n'}],
#  'camp(icl>military_quarters>thing)': [{'lemma': 'acantonamiento', 'pos': 'n'},
#   {'lemma': 'cantón', 'pos': 'n'},
#   {'lemma': 'vivac', 'pos': 'n'}],
#  'cantonment(icl>military_quarters>thing,equ>camp)': [{'lemma': 'acantonamiento',
#    'pos': 'n'}],
#  'carry(icl>have>do,equ>stock,agt>thing,obj>thing)': [{'lemma': 'acarrear',
#    'pos': 'v'}],
#  'cart(icl>pull>do,equ>haul,agt>thing,obj>thing)': [{'lemma': 'acarrear',
#    'pos': 'v'}],
#  'convey(icl>carry>do,plt>place,plf>place,agt>thing,obj>thing)': [{'lemma': 'acarrear',
#    'pos': 'v'},
#   {'lemma': 'llevar', 'pos': 'v'},
#   {'lemma': 'traer', 'pos': 'v'}],
#  'hale(icl>pull>do,equ>haul,agt>thing,obj>thing)': [{'lemma': 'acarrear',
#    'pos': 'v'}],
#  'haul(icl>draw(icl>move)>do,agt>thing,obj>concrete_thing)': [{'lemma': 'acarrear',
#    'pos': 'v'}],
#  'haul(icl>transport>do,plt>uw,plf>uw,agt>volitional_thing,obj>thing,plc>thing)': [{'lemma': 'acarrear',
#    'pos': 'v'},
#   {'lemma': 'cargar', 'pos': 'v'}],
#  'lug(icl>transport>do,plf>thing,agt>person,obj>concrete_thing)': [{'lemma': 'acarrear',
#    'pos': 'v'},
#   {'lemma': 'arrastrar', 'pos': 'v'}],
#  'stock(icl>have>do,agt>volitional_thing,obj>concrete_thing)': [{'lemma': 'acarrear',
#    'pos': 'v'}],
#  'stockpile(icl>have>do,equ>stock,agt>thing,obj>thing)': [{'lemma': 'acarrear',
#    'pos': 'v'}],
#  'tote(icl>transport>do,equ>lug,agt>thing,obj>thing)': [{'lemma': 'acarrear',
#    'pos': 'v'},
#   {'lemma': 'arrastrar', 'pos': 'v'}],
#  'tug(icl>transport>do,equ>lug,agt>thing,obj>thing)': [{'lemma': 'acarrear',
#    'pos': 'v'},
#   {'lemma': 'arrastrar', 'pos': 'v'}],
#  'draw(icl>pull>thing)': [{'lemma': 'acarreo', 'pos': 'n'},
#   {'lemma': 'arrastre', 'pos': 'n'}],
#  'haulage(icl>pull>thing,equ>draw)': [{'lemma': 'acarreo', 'pos': 'n'},
#   {'lemma': 'arrastre', 'pos': 'n'}],
#  'haul(icl>pull>thing,equ>draw)': [{'lemma': 'acarreo', 'pos': 'n'},
#   {'lemma': 'arrastre', 'pos': 'n'}],
#  'comply(icl>obey>do,agt>volitional_thing,obj>thing)': [{'lemma': 'acatar',
#    'pos': 'v'}],
#  'follow(icl>adhere>do,equ>comply,agt>thing,obj>thing)': [{'lemma': 'acatar',
#    'pos': 'v'}],
#  'affluent(icl>adj)': [{'lemma': 'acaudalado', 'pos': 'a'},
#   {'lemma': 'adinerado', 'pos': 'a'},
#   {'lemma': 'forrado', 'pos': 'a'},
#   {'lemma': 'pudiente', 'pos': 'a'}],
#  'flush(icl>adj,equ>affluent)': [{'lemma': 'acaudalado', 'pos': 'a'},
#   {'lemma': 'adinerado', 'pos': 'a'},
#   {'lemma': 'forrado', 'pos': 'a'},
#   {'lemma': 'pudiente', 'pos': 'a'}],
#  'accede(icl>yield>do,equ>submit,agt>thing,gol>thing)': [{'lemma': 'acceder',
#    'pos': 'v'},
#   {'lemma': 'deferir', 'pos': 'v'}],
#  'access(icl>reach>do,plf>thing,agt>volitional_thing,obj>concrete_thing)': [{'lemma': 'acceder',
#    'pos': 'v'}],
# ...
#    'pos': 'v'},
#   {'lemma': 'moderar', 'pos': 'v'},
#   {'lemma': 'remitir', 'pos': 'v'}],
#  'slack(icl>decrease>do,equ>slake,agt>thing,obj>thing)': [{'lemma': 'aflojar',
#    'pos': 'v'}],
#  'slack(icl>loosen>do,agt>thing,obj>thing)': [{'lemma': 'aflojar', 'pos': 'v'},
#   {'lemma': 'destensar', 'pos': 'v'}],
#  'slack_up(icl>decrease>do,equ>slack,agt>thing,obj>thing)': [{'lemma': 'aflojar',
#    'pos': 'v'},
#   {'lemma': 'moderar', 'pos': 'v'},
#   {'lemma': 'remitir', 'pos': 'v'}],
#  'slake(icl>decrease>do,agt>thing,obj>thing)': [{'lemma': 'aflojar',
#    'pos': 'v'}],
#  'tease(icl>disentangle>do,agt>thing,obj>thing)': [{'lemma': 'aflojar',
#    'pos': 'v'},
#   {'lemma': 'desatar', 'pos': 'v'}],
#  'unstuff(icl>free>do,agt>thing,obj>thing)': [{'lemma': 'aflojar',
#    'pos': 'v'}],
#  'husky(icl>adj,equ>gruff)': [{'lemma': 'afónico', 'pos': 'a'},
#   {'lemma': 'bronco', 'pos': 'a'},
#   {'lemma': 'ronco', 'pos': 'a'}],
#  'dictum(icl>declaration>thing,equ>pronouncement)': [{'lemma': 'aforismo',
#    'pos': 'n'}],
#  'say-so(icl>declaration>thing,equ>pronouncement)': [{'lemma': 'aforismo',
#    'pos': 'n'}],
#  'affront(icl>discourtesy>thing,equ>insult)': [{'lemma': 'afrenta',
#    'pos': 'n'},
#   {'lemma': 'agravio', 'pos': 'n'}],
#  'insult(icl>discourtesy>thing)': [{'lemma': 'afrenta', 'pos': 'n'},
#   {'lemma': 'agravio', 'pos': 'n'}],
#  'affront(icl>hurt>do,equ>diss,agt>thing,obj>thing)': [{'lemma': 'afrentar',
#    'pos': 'v'},
#   {'lemma': 'insultar', 'pos': 'v'}],
#  'confront(icl>do,equ>oppose,agt>volitional_thing,cag>thing,met>thing)': [{'lemma': 'afrentar',
#    'pos': 'v'},
#   {'lemma': 'afrontar', 'pos': 'v'},
#   {'lemma': 'confrontar', 'pos': 'v'}],
#  'face(icl>do,equ>confront,agt>volitional_thing,cag>thing,met>thing)': [{'lemma': 'afrentar',
#    'pos': 'v'},
#   {'lemma': 'afrontar', 'pos': 'v'},
#   {'lemma': 'confrontar', 'pos': 'v'}],
#  'insult(icl>hurt>do,equ>diss,agt>volitional_thing,met>thing,rec>volitional_thing)': [{'lemma': 'afrentar',
#    'pos': 'v'},
#   {'lemma': 'insultar', 'pos': 'v'}],
#  'brave(icl>defy>be,equ>weather,obj>thing,aoj>thing)': [{'lemma': 'afrontar',
#    'pos': 'v'},
#   {'lemma': 'desafiar', 'pos': 'v'}],
#  'brave_out(icl>defy>be,equ>weather,obj>thing,aoj>thing)': [{'lemma': 'afrontar',
#    'pos': 'v'},
#   {'lemma': 'desafiar', 'pos': 'v'}],
#  'confront(icl>deal>do,equ>face,agt>volitional_thing,cag>thing,met>thing)': [{'lemma': 'afrontar',
#    'pos': 'v'}],
#  'endure(icl>bear>be,obj>uw,aoj>person)': [{'lemma': 'afrontar', 'pos': 'v'},
#   {'lemma': 'desafiar', 'pos': 'v'}],
#  'face_up(icl>set_about>do,equ>confront,agt>volitional_thing,obj>thing)': [{'lemma': 'afrontar',
#    'pos': 'v'}],
#  'weather(icl>defy>be,obj>thing,aoj>thing)': [{'lemma': 'afrontar',
#    'pos': 'v'},
#   {'lemma': 'desafiar', 'pos': 'v'}],
#  'grit(icl>fortitude>thing,equ>backbone)': [{'lemma': 'agallas', 'pos': 'n'},
#   {'lemma': 'cojones', 'pos': 'n'}],
#  'gumption(icl>fortitude>thing,equ>backbone)': [{'lemma': 'agallas',
#    'pos': 'n'},
#   {'lemma': 'cojones', 'pos': 'n'}],
#  'clutch(icl>hold>do,agt>living_thing,obj>concrete_thing,ins>organ)': [{'lemma': 'agarrar',
#    'pos': 'v'},
#   {'lemma': 'asir', 'pos': 'v'},
#   {'lemma': 'prender', 'pos': 'v'}],
#  'grip(icl>seize>do,agt>thing,obj>thing)': [{'lemma': 'agarrar', 'pos': 'v'}],
#  'prehend(icl>take>do,equ>seize,agt>thing,obj>thing)': [{'lemma': 'agarrar',
#    'pos': 'v'},
#   {'lemma': 'asir', 'pos': 'v'},
#   {'lemma': 'prender', 'pos': 'v'}],
#  'stiffen(icl>change>occur,obj>thing)': [{'lemma': 'agarrotarse', 'pos': 'v'}],
#  'fete(icl>meet>do,equ>celebrate,agt>volitional_thing,obj>thing)': [{'lemma': 'agasajar',
#    'pos': 'v'}],
#  'sit_down(icl>do,plt>thing,agt>person)': [{'lemma': 'agazaparse',
#    'pos': 'v'}],
#  'sit(icl>change_posture>do,equ>sit_down,agt>thing)': [{'lemma': 'agazaparse',
#    'pos': 'v'}],
#  'agency(icl>administrative_unit>thing)': [{'lemma': 'agencia', 'pos': 'n'}],
#  'finagle(icl>achieve>do,equ>wangle,cob>thing,agt>volitional_thing,obj>thing)': [{'lemma': 'agenciarse',
#    'pos': 'v'},
#   {'lemma': 'amañar', 'pos': 'v'}],
#  'wangle(icl>achieve>do,agt>volitional_thing,obj>thing)': [{'lemma': 'agenciarse',
#    'pos': 'v'},
#   {'lemma': 'amañar', 'pos': 'v'}],
#  'cause(icl>physical_entity>thing,equ>causal_agent)': [{'lemma': 'agente causal',
#    'pos': 'n'}],
#  'shamus(icl>detective>thing,equ>private_detective)': [{'lemma': 'agente',
#    'pos': 'n'},
#   {'lemma': 'detective', 'pos': 'n'},
#   {'lemma': 'detective privado', 'pos': 'n'}],
#  'sherlock(icl>detective>person,equ>private_detective)': [{'lemma': 'agente',
#    'pos': 'n'},
#   {'lemma': 'detective', 'pos': 'n'},
#   {'lemma': 'detective privado', 'pos': 'n'}],
#  'constabulary(icl>force>thing,equ>police)': [{'lemma': 'agentes', 'pos': 'n'},
#   {'lemma': 'fuerzas del orden', 'pos': 'n'},
#   {'lemma': 'fuerzas del orden público', 'pos': 'n'},
#   {'lemma': 'fuerzas policiales', 'pos': 'n'},
#   {'lemma': 'guardia', 'pos': 'n'}],
#  'police(icl>force>thing)': [{'lemma': 'agentes', 'pos': 'n'},
#   {'lemma': 'fuerzas del orden', 'pos': 'n'},
#   {'lemma': 'fuerzas del orden público', 'pos': 'n'},
#   {'lemma': 'fuerzas policiales', 'pos': 'n'},
#   {'lemma': 'guardia', 'pos': 'n'}],
#  'lissome(icl>adj)': [{'lemma': 'agil', 'pos': 'a'},
#   {'lemma': 'ligero', 'pos': 'a'}],
#  'lithesome(icl>adj,equ>lissome)': [{'lemma': 'agil', 'pos': 'a'},
#   {'lemma': 'ligero', 'pos': 'a'}],
#  'supple(icl>adj,equ>lissome)': [{'lemma': 'agil', 'pos': 'a'},
#   {'lemma': 'ligero', 'pos': 'a'}],
#  'svelte(icl>adj,equ>lissome)': [{'lemma': 'agil', 'pos': 'a'},
#   {'lemma': 'ligero', 'pos': 'a'}],
#  'agio(icl>charge>thing)': [{'lemma': 'agio', 'pos': 'n'}],
#  'agiotage(icl>charge>thing,equ>agio)': [{'lemma': 'agio', 'pos': 'n'}],
#  'ado(icl>commotion>thing,equ>bustle)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'ajetreo', 'pos': 'n'},
#   {'lemma': 'alboroto', 'pos': 'n'},
#   {'lemma': 'bullicio', 'pos': 'n'},
#   {'lemma': 'movimiento', 'pos': 'n'},
#   {'lemma': 'tejemaneje', 'pos': 'n'},
#   {'lemma': 'trajín', 'pos': 'n'}],
#  'agitation(icl>disturbance>thing)': [{'lemma': 'agitación', 'pos': 'n'}],
#  'agitation(icl>psychological_state>thing)': [{'lemma': 'agitación',
#    'pos': 'n'}],
#  'agitation(icl>turbulence>thing)': [{'lemma': 'agitación', 'pos': 'n'}],
#  'bustle(icl>commotion>thing)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'ajetreo', 'pos': 'n'},
#   {'lemma': 'alboroto', 'pos': 'n'},
#   {'lemma': 'bullicio', 'pos': 'n'},
#   {'lemma': 'movimiento', 'pos': 'n'},
#   {'lemma': 'tejemaneje', 'pos': 'n'},
#   {'lemma': 'trajín', 'pos': 'n'}],
#  'disquiet(icl>discomposure>thing)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'desasosiego', 'pos': 'n'},
#   {'lemma': 'inquietud', 'pos': 'n'}],
#  'ferment(icl>turbulence>thing,equ>agitation)': [{'lemma': 'agitación',
#    'pos': 'n'}],
#  'flap(icl>wave>thing)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'revoloteo', 'pos': 'n'}],
#  'flurry(icl>commotion>thing,equ>bustle)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'ajetreo', 'pos': 'n'},
#   {'lemma': 'alboroto', 'pos': 'n'},
#   {'lemma': 'bullicio', 'pos': 'n'},
#   {'lemma': 'movimiento', 'pos': 'n'},
#   {'lemma': 'tejemaneje', 'pos': 'n'},
#   {'lemma': 'trajín', 'pos': 'n'}],
#  'fluster(icl>discomposure>thing,equ>perturbation)': [{'lemma': 'agitación',
#    'pos': 'n'},
#   {'lemma': 'azoramiento', 'pos': 'n'},
#   {'lemma': 'confusión', 'pos': 'n'},
#   {'lemma': 'inquietud', 'pos': 'n'}],
#  'flutter(icl>disorder>thing,equ>disturbance)': [{'lemma': 'agitación',
#    'pos': 'n'},
#   {'lemma': 'alboroto', 'pos': 'n'},
#   {'lemma': 'barrila', 'pos': 'n'},
#   {'lemma': 'bullicio', 'pos': 'n'},
#   {'lemma': 'cacao', 'pos': 'n'},
#   {'lemma': 'conmoción', 'pos': 'n'},
#   {'lemma': 'disturbios', 'pos': 'n'},
#   {'lemma': 'lío', 'pos': 'n'},
#   {'lemma': 'movida', 'pos': 'n'},
#   {'lemma': 'perturbación', 'pos': 'n'},
#   {'lemma': 'ruido', 'pos': 'n'},
#   {'lemma': 'sarao', 'pos': 'n'},
#   {'lemma': 'tomate', 'pos': 'n'},
#   {'lemma': 'trapisonda', 'pos': 'n'},
#   {'lemma': 'trastorno', 'pos': 'n'}],
#  'flutter(icl>wave>thing,equ>flap)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'revoloteo', 'pos': 'n'}],
#  'fuss(icl>commotion>thing,equ>bustle)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'ajetreo', 'pos': 'n'},
#   {'lemma': 'alboroto', 'pos': 'n'},
#   {'lemma': 'bullicio', 'pos': 'n'},
#   {'lemma': 'movimiento', 'pos': 'n'},
#   {'lemma': 'tejemaneje', 'pos': 'n'},
#   {'lemma': 'trajín', 'pos': 'n'}],
#  'hullabaloo(icl>disturbance>thing,equ>agitation)': [{'lemma': 'agitación',
#    'pos': 'n'},
#   {'lemma': 'algarabía', 'pos': 'n'},
#   {'lemma': 'barbulla', 'pos': 'n'},
#   {'lemma': 'batahola', 'pos': 'n'},
#   {'lemma': 'greguería', 'pos': 'n'},
#   {'lemma': 'griterío', 'pos': 'n'},
#   {'lemma': 'vocería', 'pos': 'n'},
#   {'lemma': 'zalagarda', 'pos': 'n'},
#   {'lemma': 'zambeque', 'pos': 'n'}],
#  'hustle(icl>commotion>thing,equ>bustle)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'ajetreo', 'pos': 'n'},
#   {'lemma': 'alboroto', 'pos': 'n'},
#   {'lemma': 'bullicio', 'pos': 'n'},
#   {'lemma': 'movimiento', 'pos': 'n'},
#   {'lemma': 'tejemaneje', 'pos': 'n'},
#   {'lemma': 'trajín', 'pos': 'n'}],
#  'perturbation(icl>discomposure>thing)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'azoramiento', 'pos': 'n'},
#   {'lemma': 'confusión', 'pos': 'n'},
#   {'lemma': 'inquietud', 'pos': 'n'}],
#  'restlessness(icl>nervousness>thing)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'desasosiego', 'pos': 'n'},
#   {'lemma': 'inquietud', 'pos': 'n'},
#   {'lemma': 'intranquilidad', 'pos': 'n'}],
#  'stir(icl>agitation>thing)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'conmoción', 'pos': 'n'}],
#  'stir(icl>commotion>thing,equ>bustle)': [{'lemma': 'agitación', 'pos': 'n'},
#   {'lemma': 'ajetreo', 'pos': 'n'},
#   {'lemma': 'alboroto', 'pos': 'n'},
#   {'lemma': 'bullicio', 'pos': 'n'},
#   {'lemma': 'movimiento', 'pos': 'n'},
#   {'lemma': 'tejemaneje', 'pos': 'n'},
#   {'lemma': 'trajín', 'pos': 'n'}],
#  'uneasiness(icl>discomposure>thing,equ>disquiet)': [{'lemma': 'agitación',
#    'pos': 'n'},
#   {'lemma': 'desasosiego', 'pos': 'n'},
#   {'lemma': 'inquietud', 'pos': 'n'}],
#  'uneasiness(icl>nervousness>thing,equ>restlessness)': [{'lemma': 'agitación',
#    'pos': 'n'},
#   {'lemma': 'desasosiego', 'pos': 'n'},
#   {'lemma': 'inquietud', 'pos': 'n'},
#   {'lemma': 'intranquilidad', 'pos': 'n'}],
#  'upheaval(icl>disturbance>thing,equ>agitation)': [{'lemma': 'agitación',
#    'pos': 'n'},
#   {'lemma': 'algarabía', 'pos': 'n'},
#   {'lemma': 'barbulla', 'pos': 'n'},
#   {'lemma': 'batahola', 'pos': 'n'},
#   {'lemma': 'greguería', 'pos': 'n'},
#   {'lemma': 'griterío', 'pos': 'n'},
#   {'lemma': 'vocería', 'pos': 'n'},
#   {'lemma': 'zalagarda', 'pos': 'n'},
#   {'lemma': 'zambeque', 'pos': 'n'}],
#  'itchy(icl>adj,equ>antsy)': [{'lemma': 'agitado', 'pos': 'a'},
#   {'lemma': 'inquieto', 'pos': 'a'}],
#  'agitate(icl>move>occur,equ>stir,obj>thing)': [{'lemma': 'agitarse',
#    'pos': 'v'}],
#  'budge(icl>move>occur,equ>stir,obj>concrete_thing)': [{'lemma': 'agitarse',
#    'pos': 'v'}],
#  'shift(icl>move>occur,equ>stir,obj>thing)': [{'lemma': 'agitarse',
#    'pos': 'v'}],
#  'agitate(icl>move>do,agt>thing,obj>thing)': [{'lemma': 'agitar', 'pos': 'v'}],
#  'agitate(icl>move>occur,equ>shake,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'agitate(icl>provoke>do,agt>person,obj>volitional_thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'beat(icl>move>cause>do,agt>thing,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'},
#   {'lemma': 'aletear', 'pos': 'v'},
#   {'lemma': 'batir', 'pos': 'v'}],
#  'boil(icl>be,equ>seethe,rsn>abstract_thing,aoj>person)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'boil(icl>move>be,equ>churn,aoj>thing)': [{'lemma': 'agitar', 'pos': 'v'}],
#  'commove(icl>move>do,equ>agitate,agt>thing,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'didder(icl>move_involuntarily>occur,equ>shake,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'},
#   {'lemma': 'menear', 'pos': 'v'},
#   {'lemma': 'sacudir', 'pos': 'v'}],
#  'disturb(icl>move>do,equ>agitate,agt>thing,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'dither(icl>fuss>occur,obj>thing)': [{'lemma': 'agitar', 'pos': 'v'},
#   {'lemma': 'inquietarse', 'pos': 'v'}],
#  'flap(icl>fuss>occur,equ>dither,obj>thing)': [{'lemma': 'agitar', 'pos': 'v'},
#   {'lemma': 'inquietarse', 'pos': 'v'}],
#  'flap(icl>move>do,equ>beat,agt>living_thing,ins>thing)': [{'lemma': 'agitar',
#    'pos': 'v'},
#   {'lemma': 'aletear', 'pos': 'v'},
#   {'lemma': 'batir', 'pos': 'v'}],
#  'flap(icl>move>occur,equ>beat,obj>thing)': [{'lemma': 'agitar', 'pos': 'v'},
#   {'lemma': 'aletear', 'pos': 'v'}],
#  'foment(icl>provoke>do,equ>agitate,agt>person,obj>volitional_thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'jar(icl>move>occur,equ>jolt,obj>concrete_thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'jolt(icl>move>occur,obj>concrete_thing)': [{'lemma': 'agitar', 'pos': 'v'}],
#  'moil(icl>move>occur,equ>churn,obj>thing)': [{'lemma': 'agitar', 'pos': 'v'}],
#  'pother(icl>fuss>occur,equ>dither,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'},
#   {'lemma': 'inquietarse', 'pos': 'v'}],
#  'raise_up(icl>move>do,equ>agitate,agt>thing,obj>concrete_thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'roil(icl>move>occur,equ>churn,obj>thing)': [{'lemma': 'agitar', 'pos': 'v'}],
#  'shake(icl>move(icl>cause)>do,agt>thing,obj>concrete_thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'shake(icl>move>occur,rsn>thing,obj>concrete_thing)': [{'lemma': 'agitar',
#    'pos': 'v'},
#   {'lemma': 'menear', 'pos': 'v'},
#   {'lemma': 'sacudir', 'pos': 'v'}],
#  'shake_up(icl>move>do,equ>agitate,agt>thing,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'stir(icl>budge>do,agt>thing,obj>concrete_thing)': [{'lemma': 'agitar',
#    'pos': 'v'},
#   {'lemma': 'moverse', 'pos': 'v'},
#   {'lemma': 'remover', 'pos': 'v'},
#   {'lemma': 'revolver', 'pos': 'v'}],
#  'stir_up(icl>move>do,equ>agitate,agt>thing,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'stir_up(icl>provoke>do,equ>agitate,agt>thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'vex(icl>move>do,equ>agitate,agt>thing,obj>thing)': [{'lemma': 'agitar',
#    'pos': 'v'}],
#  'aggregate(icl>sum>thing)': [{'lemma': 'aglomeración', 'pos': 'n'},
#   {'lemma': 'conglomeración', 'pos': 'n'}],
#  'crush(icl>crowd>thing)': [{'lemma': 'aglomeración', 'pos': 'n'},
#   {'lemma': 'gentío', 'pos': 'n'},
#   {'lemma': 'muchedumbre', 'pos': 'n'}],
#  'jam(icl>crowd>thing,equ>crush)': [{'lemma': 'aglomeración', 'pos': 'n'},
#   {'lemma': 'gentío', 'pos': 'n'},
#   {'lemma': 'muchedumbre', 'pos': 'n'}],
#  'chipboard(icl>board>thing)': [{'lemma': 'aglomerado', 'pos': 'n'},
#   {'lemma': 'conglomerado', 'pos': 'n'}],
#  'silver(icl>noble_metal>thing)': [{'lemma': 'Ag', 'pos': 'n'},
#   {'lemma': 'número atómico 47', 'pos': 'n'}],
#  'overstrung(icl>adj,equ>edgy)': [{'lemma': 'agobiado', 'pos': 'a'},
#   {'lemma': 'inquieto', 'pos': 'a'},
#   {'lemma': 'intranquilo', 'pos': 'a'}],
#  'restive(icl>adj,equ>edgy)': [{'lemma': 'agobiado', 'pos': 'a'},
#   {'lemma': 'inquieto', 'pos': 'a'},
#   {'lemma': 'intranquilo', 'pos': 'a'}],
#  'throng(icl>gathering>thing,equ>multitude)': [{'lemma': 'agolpamiento',
#    'pos': 'n'},
#   {'lemma': 'caterva', 'pos': 'n'},
#   {'lemma': 'gentío', 'pos': 'n'},
#   {'lemma': 'muchedumbre', 'pos': 'n'},
#   {'lemma': 'multitud', 'pos': 'n'},
#   {'lemma': 'runfla', 'pos': 'n'}],
#  'agony(icl>pain>thing)': [{'lemma': 'agonía', 'pos': 'n'}],
#  'excruciation(icl>pain>thing,equ>agony)': [{'lemma': 'agonía', 'pos': 'n'}],
#  'hurt(icl>pain>thing,equ>suffering)': [{'lemma': 'agonía', 'pos': 'n'},
#   {'lemma': 'mal', 'pos': 'n'},
#   {'lemma': 'martirio', 'pos': 'n'},
#   {'lemma': 'suplicio', 'pos': 'n'},
#   {'lemma': 'tormento', 'pos': 'n'}],
#  'baleful(icl>adj)': [{'lemma': 'agorero', 'pos': 'a'},
#   {'lemma': 'amenazador', 'pos': 'a'}],
#  'minacious(icl>adj,equ>baleful)': [{'lemma': 'agorero', 'pos': 'a'},
#   {'lemma': 'amenazador', 'pos': 'a'}],
#  'minatory(icl>adj,equ>baleful)': [{'lemma': 'agorero', 'pos': 'a'},
#   {'lemma': 'amenazador', 'pos': 'a'}],
#  'aweary(icl>adj)': [{'lemma': 'agotado', 'pos': 'a'},
#   {'lemma': 'cansado', 'pos': 'a'},
#   {'lemma': 'exhausto', 'pos': 'a'},
#   {'lemma': 'extenuado', 'pos': 'a'},
#   {'lemma': 'fatigado', 'pos': 'a'}],
#  ...}

# %%
with open("../resources/unl2esp.pickle", "wb") as f:
    pickle.dump(dic, f)

# %% [markdown]
# ## Traductor Eng2UNL

# %%
class Eng2UNLTranslator():
    
    def __init__(self, file = "../resources/eng2unl.pickle"):
        with open(file, "rb") as f:
            self.dic = pickle.load(f)
            
    def get_combinations(self, tokens):
        """
        Calcula todas las combinaciones de los tokens dados.
        """
        result = [" ".join(tokens[i: j]) for i in range(len(tokens)) for j in range(i + 1, len(tokens) + 1) if j-i > 1]
        result.sort(reverse = True, key = len)
        return result
            
    def translate(self, tokens):
        """
        Recibe una lista de tokens en inglés lematizados (salida de lematizados) y devuelve una lista de uws.
        """
        print(f"\tQuery original = {tokens}")
        lemmas = [token["lemma"] for token in tokens]
        combinations = self.get_combinations(lemmas)
        
        translated = []
        
        for combination in combinations: # primero buscamos la uw de las expresiones en inglés
            if combination in self.dic:
                print(f"\t\tCombinación traducida {combination}")
                uws = [translation["uw"] for translation in self.dic[combination]]
                translated += uws
                
                # borramos las expresiones que tienen un lema ya traducido y los lemas traducidos
                combinations.remove(combination)
                for token in combination.split(" "):
                    for c in combinations: # combinaciones que quedan
                        if token in c: # la combinación tiene un lemma a traducido
                            combinations.remove(c)
                    lemmas.remove(token)

        # ahora traducimos los lemmas restantes
        for token in tokens:
            if token["lemma"] in lemmas: # no se ha traducido
                lemma = token["lemma"]
                if lemma in self.dic:
                    uws = [translation["uw"] for translation in self.dic[lemma] if translation["pos"] == token["pos"]]
                    translated += uws
                else:
                    print(f"\t\tNo se ha podido encontrar {lemma} en el diccionario Eng2UNL")
                
        print(f"\tUWs encontradas = {translated}")
        return translated

# %%
eng2unl = Eng2UNLTranslator()

# %%
eng2unl.translate([
    {'lemma': 'girl', 'pos': 'n'},
    {'lemma': 'beautiful', 'pos': 'a'},
])
# Out:
# Query original = [{'lemma': 'girl', 'pos': 'n'}, {'lemma': 'beautiful', 'pos': 'a'}]
# UWs encontradas = ['girl(icl>child>person,ant>boy)', 'girl(icl>child>person,equ>daughter,ant>boy,pos>person)', 'girl(icl>person,equ>girlfriend,pos>man)', 'girl(icl>person,equ>woman)', 'girl(icl>virgin>person)', 'girl(icl>woman>thing)', 'beautiful(icl>adj,ant>ugly)', 'beautiful(icl>adj)']
# ['girl(icl>child>person,ant>boy)',
#  'girl(icl>child>person,equ>daughter,ant>boy,pos>person)',
#  'girl(icl>person,equ>girlfriend,pos>man)',
#  'girl(icl>person,equ>woman)',
#  'girl(icl>virgin>person)',
#  'girl(icl>woman>thing)',
#  'beautiful(icl>adj,ant>ugly)',
#  'beautiful(icl>adj)']

# %% [markdown]
# ## Traductor UNL2Esp

# %%
class UNL2EspTranslator():
    
    def __init__(self, file = "../resources/unl2esp.pickle"):
        with open(file, "rb") as f:
            self.dic = pickle.load(f)
            
    def get_combinations(self, tokens):
        """
        Calcula todas las combinaciones de los tokens dados.
        """
        result = [" ".join(tokens[i: j]) for i in range(len(tokens)) for j in range(i + 1, len(tokens) + 1) if j-i > 1]
        result.sort(reverse = True, key = len)
        return result
            
    def translate(self, uws):
        """
        Recibe una lista de uws y devuelve una lista de tokens en español.
        """
        print(f"\tUWs = {uws}")
        
        translated = []
        
        for uw in uws:
            if uw in self.dic:
                translations = [translation["lemma"] for translation in self.dic[uw]]
                translated += translations
            else:
                print(f"\t\tUW no encontrada en el diccionario de español: {uw}")
                
        print(f"\tTraducción al español = {translated}")
        return list(set(translated)) # para eliminar duplicados

# %%
unl2esp = UNL2EspTranslator()
unl2esp.translate(['girl(icl>child>person,ant>boy)',
 'girl(icl>child>person,equ>daughter,ant>boy,pos>person)',
 'girl(icl>person,equ>girlfriend,pos>man)',
 'girl(icl>person,equ>woman)',
 'girl(icl>virgin>person)',
 'girl(icl>woman>thing)',
 'beautiful(icl>adj,ant>ugly)',
 'beautiful(icl>adj)'])
# Out:
# UWs = ['girl(icl>child>person,ant>boy)', 'girl(icl>child>person,equ>daughter,ant>boy,pos>person)', 'girl(icl>person,equ>girlfriend,pos>man)', 'girl(icl>person,equ>woman)', 'girl(icl>virgin>person)', 'girl(icl>woman>thing)', 'beautiful(icl>adj,ant>ugly)', 'beautiful(icl>adj)']
# 	UW no encontrada en el diccionario de español: girl(icl>child>person,equ>daughter,ant>boy,pos>person)
# 	UW no encontrada en el diccionario de español: girl(icl>person,equ>woman)
# 	UW no encontrada en el diccionario de español: girl(icl>virgin>person)
# 	UW no encontrada en el diccionario de español: girl(icl>woman>thing)
# Traducción al español = ['chica', 'muchacha', 'chica', 'bello', 'bonito', 'hermoso', 'bello', 'bonito']
# ['chica', 'hermoso', 'bonito', 'bello', 'muchacha']

# %% [markdown]
# ## Traductor

# %%
class Translator():
    
    def __init__(self):
        self.eng2unl = Eng2UNLTranslator()
        self.unl2esp = UNL2EspTranslator()
        
    def translate(self, salida_preprocesado):
        print("Traduciendo a UNL...")
        uws = self.eng2unl.translate(salida_preprocesado)
        print("Traduciendo a ESP...")
        translations = self.unl2esp.translate(uws)
        return list(set(translations))

# %% [markdown]
# # Indexador

# %%
class MyCorpus:
        
    def __init__(self, docs, dictionary):
        self.docs = docs
        self.dictionary = dictionary

    def __iter__(self):
        for doc in self.docs:
            yield self.dictionary.doc2bow(doc)

# %%
class Indexer():       
    
    def __init__(self, path_docs = "../documents/*/*.txt", dictionary = None, bow = None):
        self.pipeline = LemmatizerTagger("es_dep_news_trf", StopwordsRemover(STOPWORDS_SPANISH, Tokenizer(SymbolRemover())))
        self.repository = [open(doc, "r", encoding = "utf-8").read() for doc in glob.glob(path_docs)]
        if not (dictionary and bow):
            self.documents = Parallel(n_jobs = 12, verbose = 50)(delayed(self._preprocess_doc)(doc) for doc in glob.glob(path_docs))
        if dictionary:
            self.dictionary = corpora.Dictionary.load(dictionary)
        if bow:
            self.bow = corpora.MmCorpus(bow)
        
    def index(self):
        """
        Crea el diccionario de la colección y la bolsa de palabras.
        """
        self.dictionary = self._create_dictionary()
        self.dictionary.save("../resources/dictionary.dict")
        self.bow = MyCorpus(self.documents, self.dictionary)
        corpora.MmCorpus.serialize("../resources/bow.mm", self.bow, metadata=True)
        
    def _create_dictionary(self):
        """
        Función específica encargada de crear y guardar el diccionario.
        """
        dictionary = corpora.Dictionary(doc for doc in self.documents)
        return dictionary
        
    def _preprocess_doc(self, doc):
        with open(doc, "r", encoding = "utf-8") as f:
            content = f.read()
        return [token["lemma"] for token in self.pipeline.execute(content)]

# %%
indexer = Indexer()
# Out:
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done   1 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=12)]: Done   2 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=12)]: Done   3 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=12)]: Done   4 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=12)]: Done   5 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=12)]: Done   6 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=12)]: Done   7 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=12)]: Done   8 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=12)]: Done   9 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=12)]: Done  10 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=12)]: Done  11 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=12)]: Done  12 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=12)]: Done  13 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=12)]: Done  14 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=12)]: Done  15 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=12)]: Done  16 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=12)]: Done  17 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=12)]: Done  18 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=12)]: Done  19 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=12)]: Done  20 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=12)]: Done  21 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=12)]: Done  22 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=12)]: Done  23 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=12)]: Done  24 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=12)]: Done  25 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=12)]: Done  27 tasks      | elapsed:   40.3s
# [Parallel(n_jobs=12)]: Done  28 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=12)]: Done  29 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=12)]: Done  30 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=12)]: Done  31 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=12)]: Done  32 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=12)]: Done  33 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=12)]: Done  34 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=12)]: Done  35 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=12)]: Done  36 tasks      | elapsed:   50.3s
# [Parallel(n_jobs=12)]: Done  37 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=12)]: Done  38 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=12)]: Done  39 tasks      | elapsed:   55.4s
# [Parallel(n_jobs=12)]: Done  40 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=12)]: Done  41 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=12)]: Done  42 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=12)]: Done  43 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=12)]: Done  44 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=12)]: Done  45 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=12)]: Done  46 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=12)]: Done  47 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=12)]: Done  48 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=12)]: Done  49 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=12)]: Done  50 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=12)]: Done  51 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=12)]: Done  52 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=12)]: Done  53 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=12)]: Done  54 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=12)]: Done  55 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=12)]: Done  56 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=12)]: Done  57 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=12)]: Done  58 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=12)]: Done  59 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=12)]: Done  60 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=12)]: Done  61 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=12)]: Done  62 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=12)]: Done  63 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=12)]: Done  64 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=12)]: Done  65 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=12)]: Done  66 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=12)]: Done  67 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=12)]: Done  68 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=12)]: Done  69 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=12)]: Done  70 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=12)]: Done  71 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=12)]: Done  72 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=12)]: Done  73 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=12)]: Done  74 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=12)]: Done  75 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=12)]: Done  76 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=12)]: Done  77 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=12)]: Done  78 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=12)]: Done  79 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=12)]: Done  80 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=12)]: Done  81 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=12)]: Done  82 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=12)]: Done  83 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=12)]: Done  84 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=12)]: Done  85 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=12)]: Done  86 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=12)]: Done  87 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=12)]: Done  88 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=12)]: Done  89 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=12)]: Done  90 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=12)]: Done  91 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=12)]: Done  92 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=12)]: Done  93 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=12)]: Done  94 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=12)]: Done  95 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=12)]: Done  96 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=12)]: Done  97 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=12)]: Done  98 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=12)]: Done  99 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=12)]: Done 100 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=12)]: Done 101 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=12)]: Done 102 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=12)]: Done 103 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=12)]: Done 104 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=12)]: Done 105 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=12)]: Done 106 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=12)]: Done 107 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=12)]: Done 108 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=12)]: Done 109 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=12)]: Done 110 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=12)]: Done 111 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=12)]: Done 112 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=12)]: Done 113 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=12)]: Done 114 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=12)]: Done 115 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=12)]: Done 116 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=12)]: Done 117 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=12)]: Done 118 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=12)]: Done 119 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=12)]: Done 120 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=12)]: Done 121 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=12)]: Done 122 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=12)]: Done 123 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=12)]: Done 124 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=12)]: Done 125 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=12)]: Done 126 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=12)]: Done 127 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=12)]: Done 128 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=12)]: Done 129 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done 130 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done 131 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done 132 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done 133 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done 134 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done 135 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=12)]: Done 136 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=12)]: Done 137 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=12)]: Done 138 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=12)]: Done 139 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=12)]: Done 140 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=12)]: Done 141 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=12)]: Done 142 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=12)]: Done 143 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=12)]: Done 144 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=12)]: Done 145 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=12)]: Done 146 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=12)]: Done 147 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=12)]: Done 148 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=12)]: Done 149 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=12)]: Done 150 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=12)]: Done 151 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=12)]: Done 152 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=12)]: Done 153 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=12)]: Done 154 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=12)]: Done 155 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=12)]: Done 156 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=12)]: Done 157 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=12)]: Done 158 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=12)]: Done 159 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=12)]: Done 160 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=12)]: Done 161 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=12)]: Done 162 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=12)]: Done 163 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=12)]: Done 164 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=12)]: Done 165 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=12)]: Done 166 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=12)]: Done 167 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=12)]: Done 168 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=12)]: Done 169 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=12)]: Done 170 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=12)]: Done 171 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=12)]: Done 172 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=12)]: Done 173 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=12)]: Done 174 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=12)]: Done 175 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=12)]: Done 177 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=12)]: Done 182 out of 200 | elapsed:  4.1min remaining:   24.2s
# [Parallel(n_jobs=12)]: Done 187 out of 200 | elapsed:  4.2min remaining:   17.3s
# [Parallel(n_jobs=12)]: Done 192 out of 200 | elapsed:  4.3min remaining:   10.5s
# [Parallel(n_jobs=12)]: Done 197 out of 200 | elapsed:  4.4min remaining:    3.9s
# [Parallel(n_jobs=12)]: Done 200 out of 200 | elapsed:  4.4min finished

# %%
indexer.index()

# %%
indexer.documents[:5]
# Out:
# [['aceptémoslo',
#   'perder',
#   'peso',
#   'rápido',
#   'indoloro',
#   'sencillo',
#   'recomendación',
#   'básico',
#   'claro',
#   'restringir',
#   'comida',
#   'favorito',
#   'apostar',
#   'alimento',
#   'bajo',
#   'grasa',
#   'carbohidrato',
#   'azúcar',
#   'sumar él',
#   'rutina',
#   'ejercicio',
#   'regular',
#   'fuerza',
#   'voluntad',
#   'soler',
#   'frecuente',
#   'recaída',
#   'oportunidad',
#   'desperdiciada',
#   'llegado',
#   'punto',
#   'conveniente',
#   'apostar',
#   'pérdida',
#   'peso',
#   'duradero',
#   'prolongado',
#   'fácil',
#   'incómodo',
#   'duro',
#   'tarea',
#   'adelgazar',
#   'realidad',
#   'truco',
#   'sorprendentemente',
#   'fácil',
#   'forma',
#   'deshacer yo',
#   'kilo',
#   'sobrar',
#   'revista',
#   'eat',
#   'this',
#   'not',
#   'that',
#   'elaborado',
#   'lista',
#   'ver',
#   'continuación',
#   'cepilir él tú',
#   'diente',
#   'parecer',
#   'tontería',
#   'día',
#   'noche',
#   'quedar',
#   'hambre',
#   'optado',
#   'comida',
#   'ligero',
#   'forma',
#   'eficiente',
#   'resistir',
#   'tentación',
#   'abrir',
#   'nevera',
#   'pasar',
#   'cepillar tú',
#   'diente',
#   'minuto',
#   'terminado',
#   'plato',
#   'corroborar',
#   'liso',
#   'kiersky',
#   'schreiber',
#   'coach',
#   'estadounidense',
#   'experto',
#   'adelgazamiento',
#   'asegurar',
#   'apuesta',
#   'higiene',
#   'bucal',
#   'ingerir',
#   'porción',
#   'comida',
#   'probable',
#   'quitar',
#   'hambre',
#   'mínimo',
#   'dar',
#   'pereza',
#   'volver',
#   'meter',
#   'boca',
#   'dejar él',
#   'limpio',
#   'hacer',
#   'comida',
#   'parecer',
#   'grande',
#   'hambre',
#   'componente',
#   'psicológico',
#   'repente',
#   'ver',
#   'plato',
#   'lleno',
#   'terminar',
#   'sentir',
#   'saciado',
#   'simplemente',
#   'ver',
#   'rama',
#   'lechuga',
#   'diminuto',
#   'filete',
#   'pollo',
#   'extender',
#   'comida',
#   'plato',
#   'engañar',
#   'vista',
#   'estómago',
#   'engañar',
#   'mente',
#   'realidad',
#   'comer',
#   'hacer',
#   'pausa',
#   'comer',
#   'bocado',
#   'bocado',
#   'responder',
#   'mail',
#   'jugar',
#   'solitario',
#   'móvil',
#   'útil',
#   'pequeño',
#   'parada',
#   'medida',
#   'ingerir',
#   'comida',
#   'plato',
#   'sentir',
#   'estómago',
#   'lleno',
#   'ralentizar',
#   'máximo',
#   'ritmo',
#   'comida',
#   'consejo',
#   'útil',
#   'adelgazar',
#   'comer',
#   'despacio',
#   'engañar',
#   'estómago',
#   'hacer él',
#   'creer',
#   'comido',
#   'demasiado',
#   'realidad',
#   'cantidad',
#   'reñido',
#   'cantidad',
#   'porción',
#   'cambiar',
#   'dieta',
#   'ocasión',
#   'entrar',
#   'dieta',
#   'adelgazamiento',
#   'significar',
#   'adiós',
#   'plato',
#   'favorito',
#   'encantar',
#   'mar',
#   'sabroso',
#   'adorar',
#   'hamburguesa',
#   'comprar él',
#   'carne',
#   'apostar',
#   'vegetariana',
#   'libre',
#   'caloría',
#   'encantar',
#   'dulce',
#   'rico',
#   'azúcar',
#   'intercambiar él',
#   'pieza',
#   'fruta',
#   'dulce',
#   'general',
#   'modificar',
#   'alimento',
#   'gustar',
#   'recordar yo',
#   'adoptar',
#   'forma',
#   'comida',
#   'basura',
#   'mundo',
#   'dieta',
#   'permitir',
#   'día',
#   'semana',
#   'descanso',
#   'entregar tú',
#   'divino',
#   'placer',
#   'alimento',
#   'procesado',
#   'repleto',
#   'carbohidrato',
#   'caso',
#   'acuerdo',
#   'mundo',
#   'volver',
#   'tipo',
#   'comida',
#   'correr',
#   'riesgo',
#   'esfuerzo',
#   'garete',
#   'querer',
#   'marcha',
#   'atrás',
#   'demasiado',
#   'tarde',
#   'conocer',
#   'motivación',
#   'decir',
#   'principio',
#   'cumplir',
#   'objetivo',
#   'fitness',
#   'depender',
#   'medido',
#   'fuerza',
#   'voluntad',
#   'emplear',
#   'actitud',
#   'planteado',
#   'perder',
#   'peso',
#   'querer',
#   'frente',
#   'espejo',
#   'largo',
#   'comenzar',
#   'notar',
#   'cuerpo',
#   'resistente',
#   'físicamente',
#   'forma',
#   'generalmente',
#   'motivación',
#   'detrás',
#   'conocer',
#   'sentar',
#   'gana',
#   'tirar',
#   'toalla',
#   'recordar',
#   'empezar',
#   'reto',
#   'querer',
#   'obtener',
#   'cambio',
#   'aplicar',
#   'cambio',
#   'estilo',
#   'vida'],
#  ['recuento',
#   'daño',
#   'irrumpir',
#   'ola',
#   'virus',
#   'golpear él',
#   'salud',
#   'mental',
#   'incluido',
#   'olvidado',
#   'pandemia',
#   'ausente',
#   'debate',
#   'político',
#   'incrustado',
#   'vida',
#   'capa',
#   'entero',
#   'sociedad',
#   'tabú',
#   'suicidio',
#   'presente',
#   'fantasma',
#   'creciente',
#   'ir',
#   'parte',
#   'transversal',
#   'porcentaje',
#   'echar él',
#   'mano',
#   'cabeza',
#   'sectorial',
#   'médico',
#   'material',
#   'sanitario',
#   'respaldo',
#   'psicológico',
#   'necesitar',
#   'generacional',
#   'padre',
#   'preocupación',
#   'abierto',
#   'hijo',
#   'cicatriz',
#   'cerrar',
#   'generación',
#   'covid',
#   'dañado',
#   'altura',
#   'ola',
#   'durante',
#   'pandemia',
#   'número',
#   'adulto',
#   'problema',
#   'salud',
#   'mental',
#   'crecer',
#   'washington',
#   'post',
#   'mitad',
#   'población',
#   'adulto',
#   'salto',
#   'punto',
#   'covid',
#   'aislamiento',
#   'social',
#   'soledad',
#   'pérdida',
#   'preocupación',
#   'económico',
#   'miedo',
#   'contraer',
#   'virus',
#   'factor',
#   'contribuir',
#   'dato',
#   'síntoma',
#   'depresión',
#   'afectar',
#   'comparado',
#   'año',
#   'seriamente',
#   'suicidio',
#   'cifra',
#   'crecer',
#   'joven',
#   'año',
#   'aumentar',
#   'suicidio',
#   'casi',
#   'país',
#   'publicar',
#   'estadística',
#   'suicidio',
#   'retraso',
#   'año',
#   'imagen',
#   'completo',
#   'marcado',
#   'covid',
#   'experto',
#   'temer',
#   'peor',
#   'indicio',
#   'the',
#   'economist',
#   'dato',
#   'real',
#   'aumentar',
#   'llamado',
#   'línea',
#   'ayuda',
#   'frente',
#   'suicidio',
#   'número',
#   'joven',
#   'pedir',
#   'ayuda',
#   'crecido',
#   'grupo',
#   'vulnerable',
#   'correlación',
#   'estudio',
#   'the',
#   'lancet',
#   'revista',
#   'médico',
#   'equiparar',
#   'aumento',
#   'desempleo',
#   'aumento',
#   'suicidio',
#   'europa',
#   'aumento',
#   'unido',
#   'tercero',
#   'largo',
#   'historia',
#   'vínculo',
#   'epidemia',
#   'suicidio',
#   'ensombrecir',
#   'perspectiva',
#   'siglo',
#   'número',
#   'suicidio',
#   'crecer',
#   'tercio',
#   'consecuencia',
#   'pandemia',
#   'vivir',
#   'trauma',
#   'wall',
#   'street',
#   'journal',
#   'primero',
#   'estudio',
#   'encontrar',
#   'tasa',
#   'elevado',
#   'estrés',
#   'postraumático',
#   'ptsd',
#   'trabajador',
#   'salud',
#   'joven',
#   'sentir',
#   'joven',
#   'trastorno',
#   'estrés',
#   'postraumático',
#   'personal',
#   'médico',
#   'greciar',
#   'problema',
#   'salud',
#   'mental',
#   'preexistent',
#   'ansiedad',
#   'depresión',
#   'posibilidad',
#   'desarrollar',
#   'ptsd',
#   'trauma',
#   'daño',
#   'generación',
#   'covid',
#   'joven',
#   'sufrir',
#   'problema',
#   'salud',
#   'mental',
#   'mes',
#   'grupo',
#   'edad',
#   'estudio',
#   'alcance',
#   'analizar',
#   'efecto',
#   'pandemio',
#   'menor',
#   'año',
#   'the',
#   'guardian',
#   'ansiedad',
#   'problema',
#   'concentración',
#   'infelicidad',
#   'health',
#   'foundation',
#   'joven',
#   'ver',
#   'particularmente',
#   'afectado',
#   'perturbación',
#   'económico',
#   'afectado',
#   'seguridad',
#   'financiero',
#   'amenazado',
#   'perspectiva',
#   'laboral',
#   'vital',
#   'joven',
#   'obtener',
#   'apoyo',
#   'necesitar',
#   'superar',
#   'periodo',
#   'difícil',
#   'gobierno',
#   'joven',
#   'centro',
#   'política',
#   'recuperación',
#   'garantizar',
#   'mejor',
#   'oportunidad',
#   'futuro',
#   'saludable',
#   'padre',
#   'ansiedad',
#   'plazo',
#   'new',
#   'york',
#   'times',
#   'probablemente',
#   'medio',
#   'esfuerzo',
#   'dedicar',
#   'abordar',
#   'pandemia',
#   'ámbito',
#   'infantil',
#   'familiar',
#   'semana',
#   'informar',
#   'nivel',
#   'ansiedad',
#   'diario',
#   'padre',
#   'inquietud',
#   'cotidiano',
#   'gestión',
#   'inmediato',
#   'texto',
#   'ofrecer',
#   'recorrido',
#   'salida',
#   'hablo',
#   'surgir',
#   'noche',
#   'niño',
#   'dormido',
#   'apagado',
#   'netflix',
#   'surgir',
#   'tipo',
#   'pregunta',
#   'tipo',
#   'sociedad',
#   'salir',
#   'acostumbrar',
#   'muerte',
#   'masivo',
#   'discutir',
#   'veracidad',
#   'ciencia',
#   'efecto',
#   'hijo',
#   'correcto',
#   'pregunta',
#   'cambiar',
#   'nivel',
#   'sistema',
#   'operativo',
#   'cambiar',
#   'año',
#   'mirar',
#   'atrás',
#   'observar',
#   'gratitud',
#   'fase',
#   'servir',
#   'deshacer yo',
#   'equipaje',
#   'banal',
#   'inquietud',
#   'logro',
#   'profesional',
#   'habilidad',
#   'social',
#   'hijo',
#   'esforzar',
#   'allá',
#   'horizonte',
#   'funcionar',
#   'hacer yo',
#   'pregunta'],
#  ['gente',
#   'mostrar',
#   'red',
#   'social',
#   'versión',
#   'foto',
#   'exótico',
#   'vacación',
#   'comida',
#   'saludable',
#   'cena',
#   'romántico',
#   'deporte',
#   'obstante',
#   'crear',
#   'visión',
#   'idealizado',
#   'perjudicial',
#   'salud',
#   'mental',
#   'reciente',
#   'estudio',
#   'investigador',
#   'estadounidense',
#   'investigación',
#   'publicado',
#   'revista',
#   'científico',
#   'nature',
#   'communications',
#   'equipo',
#   'investigador',
#   'estadounidense',
#   'escuela',
#   'negocio',
#   'columbio',
#   'escuela',
#   'administración',
#   'kellogg',
#   'universidad',
#   'northwestern',
#   'encontrado',
#   'beneficio',
#   'psicológico',
#   'asociado',
#   'auténtico',
#   'publicación',
#   'facebook',
#   'instagram',
#   'snapchat',
#   'tiktok',
#   'incitado',
#   'publicar',
#   'forma',
#   'auténtico',
#   'asociar',
#   'ánimo',
#   'sentimiento',
#   'positivo',
#   'ánimo',
#   'negativo',
#   'participante',
#   'explicar',
#   'investigador',
#   'declaración',
#   'citado',
#   'cnn',
#   'hallazgo',
#   'sugerir',
#   'individuo',
#   'independientemente',
#   'rasgo',
#   'personalidad',
#   'beneficiar él',
#   'auténtico',
#   'red',
#   'social',
#   'estudio',
#   'analizar',
#   'dato',
#   'usuario',
#   'facebook',
#   'completado',
#   'evaluación',
#   'satisfacción',
#   'vida',
#   'personalidad',
#   'investigador',
#   'comparar',
#   'autocalificación',
#   'predicción',
#   'personalidad',
#   'usuario',
#   'basado',
#   'huella',
#   'digital',
#   'dejado',
#   'facebook',
#   'likes',
#   'publicación',
#   'averiguar',
#   'punto',
#   'facebook',
#   'representar',
#   'expresión',
#   'auténtico',
#   'personalidad',
#   'expresar',
#   'auténtico',
#   'actuar',
#   'facebook',
#   'cercano',
#   'ver',
#   'informar',
#   'mayor',
#   'nivel',
#   'satisfacción',
#   'vida',
#   'estudio',
#   'investigador',
#   'conseguir',
#   'estudiante',
#   'presentar',
#   'forma',
#   'auténtico',
#   'facebook',
#   'semana',
#   'forma',
#   'auto',
#   'idealizado',
#   'semana',
#   'equipo',
#   'encontrar',
#   'bienestar',
#   'subjetivo',
#   'estudiante',
#   'semana',
#   'pedir',
#   'postear',
#   'auténtico',
#   'vínculo',
#   'autenticidad',
#   'bienestar',
#   'general',
#   'documentado',
#   'investigación',
#   'anterior',
#   'señalar',
#   'erica',
#   'bailey',
#   'escuela',
#   'negocio',
#   'columbio',
#   'autora',
#   'estudio',
#   'caso',
#   'red',
#   'social',
#   'probable',
#   'hacer',
#   'dirección',
#   'opuesto',
#   'persona',
#   'feliz',
#   'probablemente',
#   'propenso',
#   'publicar',
#   'auténticamente',
#   'difícil',
#   'evitar',
#   'red',
#   'social',
#   'día',
#   'querer',
#   'forma',
#   'herramienta',
#   'útil',
#   'psicológicamente',
#   'apuntar',
#   'bailey',
#   'tensión',
#   'usuario',
#   'enfrentar',
#   'presentar él',
#   'idealizado',
#   'auténtico',
#   'hallazgo',
#   'demostrar',
#   'red',
#   'social',
#   'auténtico',
#   'asociar',
#   'bienestar',
#   'subjetivo',
#   'concluir'],
#  ['faceta',
#   'clave',
#   'frenético',
#   'lucha',
#   'global',
#   'pfizer',
#   'moderno',
#   'grupo',
#   'farmacéutico',
#   'emprendido',
#   'desarrollar',
#   'vacuna',
#   'viable',
#   'coronavirus',
#   'reclutamiento',
#   'decena',
#   'mil',
#   'voluntario',
#   'dispuesto',
#   'participar',
#   'ensayo',
#   'clínico',
#   'corresponsal',
#   'afp',
#   'miami',
#   'leila',
#   'macor',
#   'participar',
#   'ensayo',
#   'fase',
#   'organizado',
#   'moderno',
#   'firma',
#   'estadounidense',
#   'biotecnología',
#   'anunciar',
#   'lunes',
#   'vacuna',
#   'experimental',
#   'covid',
#   'efectividad',
#   'macor',
#   'sufrir',
#   'asma',
#   'decidir',
#   'sujeto',
#   'estudio',
#   'moderno',
#   'relatar',
#   'experiencia',
#   'comenzar',
#   'semana',
#   'padre',
#   'morir',
#   'covid',
#   'chile',
#   'decisión',
#   'delicado',
#   'padre',
#   'morir',
#   'semana',
#   'comenzar',
#   'ensayo',
#   'clínico',
#   'pfizer',
#   'moderno',
#   'fin',
#   'julio',
#   'morir',
#   'morir',
#   'gente',
#   'virus',
#   'hermano',
#   'madre',
#   'tratár',
#   'lidiar',
#   'pérdida',
#   'confinamiento',
#   'país',
#   'enfrentar',
#   'peligroso',
#   'realidad',
#   'miami',
#   'florido',
#   'general',
#   'volver',
#   'importante',
#   'foco',
#   'virus',
#   'unido',
#   'cubrir',
#   'historia',
#   'idea',
#   'activamente',
#   'ayudar',
#   'derrotar',
#   'plaga',
#   'ofrecer',
#   'paz',
#   'hablar',
#   'amigo',
#   'familiar',
#   'ayudar',
#   'concluir',
#   'asmático',
#   'peligro',
#   'potencial',
#   'efecto',
#   'secundario',
#   'vacuna',
#   'riesgo',
#   'correr',
#   'contagiar',
#   'coronavirus',
#   'decidir',
#   'participar',
#   'día',
#   'escribir',
#   'reportaje',
#   'inicio',
#   'ensayo',
#   'clínico',
#   'fase',
#   'florido',
#   'llamar',
#   'puerta',
#   'centro',
#   'investigación',
#   'sujeto',
#   'estudio',
#   'research',
#   'center',
#   'of',
#   'america',
#   'suburbio',
#   'hollywood',
#   'norte',
#   'miami',
#   'desarrollar',
#   'ensayo',
#   'pfizer',
#   'moderno',
#   'alternar',
#   'día',
#   'día',
#   'decena',
#   'centro',
#   'investigación',
#   'resto',
#   'país',
#   'reclutar',
#   'voluntario',
#   'cualquiera',
#   'ofrecer él',
#   'probabilidad',
#   'contagio',
#   'alto',
#   'camarero',
#   'médico',
#   'taxista',
#   'reportero',
#   'fijar',
#   'cita',
#   'martes',
#   'resultar',
#   'día',
#   'moderno',
#   'vacuna',
#   'placebo',
#   'poner',
#   'calcomanía',
#   'nombre',
#   'blús',
#   'llevar',
#   'consultorio',
#   'explicar',
#   'leer',
#   'documento',
#   'página',
#   'test',
#   'consistir',
#   'dosis',
#   'voluntario',
#   'recibir',
#   'dólar',
#   'año',
#   'duro',
#   'estudio',
#   'advertir',
#   'posible',
#   'efecto',
#   'secundario',
#   'dolor',
#   'inyección',
#   'fiebre',
#   'escalofrío',
#   'voluntario',
#   'ír',
#   'dividido',
#   'grupo',
#   'mitad',
#   'recibir',
#   'vacuna',
#   'mitad',
#   'placebo',
#   'cuál',
#   'cuál',
#   'enfermera',
#   'buscar',
#   'indagar',
#   'caer',
#   'grupo',
#   'placebo',
#   'gente',
#   'moderno',
#   'compilar',
#   'analice',
#   'dato',
#   'preguntar',
#   'ocurrir',
#   'hacer',
#   'test',
#   'anticuerpo',
#   'resultado',
#   'concluyent',
#   'matar',
#   'incertidumbre',
#   'decir',
#   'enfermera',
#   'tomar',
#   'presión',
#   'levantar',
#   'mirada',
#   'hablar',
#   'seriamente',
#   'placebo',
#   'importante',
#   'vacuna',
#   'imposible',
#   'ensayo',
#   'grupo',
#   'control',
#   'ayudar',
#   'humanidad',
#   'sentir',
#   'culpable',
#   'obsesionar yo',
#   'rol',
#   'ensayo',
#   'clínico',
#   'concentrar yo',
#   'objetivo',
#   'ayudar yo',
#   'superar',
#   'pandemia',
#   'dejar',
#   'preguntar',
#   'relato',
#   'dosis',
#   'enfermera',
#   'sacar',
#   'sangre',
#   'llenar',
#   'tubo',
#   'perder',
#   'test',
#   'embarazo',
#   'insistente',
#   'anticonceptivo',
#   'conocer',
#   'efecto',
#   'vacuno',
#   'feto',
#   'venir',
#   'persona',
#   'vacuno',
#   'neverito',
#   'placebo',
#   'reír',
#   'pedir',
#   'dejar',
#   'tomar',
#   'foto',
#   'histórico',
#   'martes',
#   'cualquiera',
#   'pinchazo',
#   'doler',
#   'conducir',
#   'sala',
#   'espera',
#   'medio',
#   'hora',
#   'observación',
#   'voluntario',
#   'mirar',
#   'indolentemente',
#   'teléfono',
#   'enfermera',
#   'cubano',
#   'llevar',
#   'capa',
#   'rojo',
#   'superman',
#   'capa',
#   'preguntar',
#   'héroe',
#   'mami',
#   'regalar',
#   'calcomanía',
#   'camiseta',
#   'mascarilla',
#   'lema',
#   'guerrero',
#   'covid',
#   'descargar',
#   'aplicación',
#   'regularmente',
#   'reportar',
#   'temperatura',
#   'síntoma',
#   'llegar',
#   'casa',
#   'doler',
#   'zona',
#   'inyección',
#   'tocar',
#   'vacuna',
#   'pensar',
#   'pasar',
#   'día',
#   'siguiente',
#   'googlear',
#   'inyección',
#   'suero',
#   'producir',
#   'dolor',
#   'muscular',
#   'conseguir',
#   'respuesta',
#   'dosis',
#   'mediado',
#   'septiembre',
#   'doler',
#   'día',
#   'inyección',
#   'hinchado',
#   'caliente',
#   'imposible',
#   'certeza',
#   'idea',
#   'esperar',
#   'moderno',
#   'informe',
#   'día',
#   'vacunado',
#   'dar',
#   'participar',
#   'ensayo',
#   'clínico',
#   'forma',
#   'procesar',
#   'duelo',
#   'padre',
#   'mundo',
#   'virus',
#   'dejar',
#   'regalo',
#   'diminuto',
#   'único',
#   'arma',
#   'empuñar',
#   'hacer yo',
#   'ilusión',
#   'defender'],
#  ['curva',
#   'contagio',
#   'coronavirus',
#   'mantener',
#   'españa',
#   'línea',
#   'día',
#   'reflejar',
#   'informe',
#   'actualizado',
#   'martes',
#   'ministerio',
#   'sanidad',
#   'revelar',
#   'fallecido',
#   'positivo',
#   'cifra',
#   'superior',
#   'comunicado',
#   'recuento',
#   'lunes',
#   'alejado',
#   'dato',
#   'publicado',
#   'final',
#   'octubre',
#   'principio',
#   'mes',
#   'llegar',
#   'contagio',
#   'diario',
#   'documento',
#   'sanidad',
#   'contar',
#   'persona',
#   'infectado',
#   'viernes',
#   'medio',
#   'día',
#   'caso',
#   'registrado',
#   'sumar',
#   'español',
#   'infectado',
#   'virus',
#   'inicio',
#   'pandemia',
#   'incidencia',
#   'acumulado',
#   'caso',
#   'cien',
#   'mil',
#   'habitante',
#   'bajar',
#   'lentamente',
#   'madrid',
#   'cifra',
#   'preocupante',
#   'ola',
#   'pandemia',
#   'menor',
#   'incidencia',
#   'acumulado',
#   'península',
#   'cifra',
#   'ligeramente',
#   'superior',
#   'isla',
#   'presentar',
#   'incidencia',
#   'acumulado',
#   'balear',
#   'canario',
#   'recuento',
#   'oficial',
#   'notificado',
#   'muerte',
#   'récord',
#   'ola',
#   'dato',
#   'alto',
#   'producido',
#   'noviembre',
#   'registrar',
#   'fallecimiento',
#   'día',
#   'cifra',
#   'global',
#   'deceso',
#   'ascender',
#   'fecha',
#   'defunción',
#   'semana',
#   'sanidad',
#   'muerte',
#   'contagio',
#   'remitir',
#   'curva',
#   'fallecido',
#   'preocupar',
#   'noviembre',
#   'mes',
#   'negro',
#   'ola',
#   'comparar',
#   'cifra',
#   'notificada',
#   'mes',
#   'comprobar',
#   'muerte',
#   'duplicado',
#   'sentido',
#   'octubre',
#   'pleno',
#   'subida',
#   'periodo',
#   'pandemia',
#   'contagio',
#   'rondar',
#   'día',
#   'sanidad',
#   'registrar',
#   'deceso',
#   'semana',
#   'mitad',
#   'notificado',
#   'día',
#   'aunqque',
#   'región',
#   'aumentado',
#   'número',
#   'muerte',
#   'mes',
#   'destacar',
#   'caso',
#   'asturia',
#   'informar',
#   'fallecimiento',
#   'peor',
#   'cifra',
#   'pandemia',
#   'quintuplicado',
#   'parámetro',
#   'día',
#   'frente',
#   'notificado',
#   'día',
#   'octubre',
#   'comunidad',
#   'acumular',
#   'muerte',
#   'caso',
#   'contrario',
#   'madrid',
#   'medida',
#   'establecido',
#   'región',
#   'parecer',
#   'surtido',
#   'efecto',
#   'región',
#   'inquietar',
#   'mes',
#   'presentar',
#   'cifra',
#   'bajo',
#   'fallecido',
#   'país',
#   'semana',
#   'comunicado',
#   'deceso',
#   'mes',
#   'dato',
#   'elevado',
#   'comunidad',
#   'mayoría',
#   'fallecido',
#   'concentrar él',
#   'andalucío',
#   'semana',
#   'castilla',
#   'león',
#   'asturia',
#   'aragón',
#   'valencio',
#   'centenar',
#   'encontrar',
#   'galicia',
#   'anotar',
#   'país',
#   'vasco',
#   'murcia',
#   'sumar',
#   'muerte',
#   'periodo',
#   'castilla',
#   'mancha',
#   'navarro',
#   'extremadura',
#   'madrid',
#   'canarias',
#   'rioja',
#   'debajo',
#   'fallecido',
#   'ceuta',
#   'apuntar',
#   'cantabria',
#   'melilla',
#   'balear',
#   'positivo',
#   'notificado',
#   'corresponder',
#   'prueba',
#   'diagnóstico',
#   'realizado',
#   'hora',
#   'frente',
#   'lunes',
#   'mayoría',
#   'madrid',
#   'cataluño',
#   'país',
#   'vasco',
#   'canaria',
#   'balear',
#   'menor',
#   'incidencia',
#   'medio',
#   'nacional',
#   'incidencia',
#   'acumulado',
#   'número',
#   'caso',
#   'diagnosticado',
#   'habitante',
#   'día',
#   'continúar',
#   'día',
#   'consecutivo',
#   'debajo',
#   'contagio',
#   'concreto',
#   'localizar',
#   'castilla',
#   'león',
#   'asturia',
#   'país',
#   'vasco',
#   'ceuta',
#   'riojo',
#   'melilla',
#   'inferior',
#   'positivo',
#   'canario',
#   'comunidad',
#   'parámetro',
#   'balear',
#   'hospitalización',
#   'persona',
#   'ingresado',
#   'día',
#   'lunes',
#   'andalucía',
#   'castilla',
#   'león',
#   'asturia',
#   'castilla',
#   'león',
#   'paciente',
#   'trasladado',
#   'cuidado',
#   'intensivo',
#   'periodo',
#   'enfermo',
#   'requerido',
#   'unidad',
#   'hospitalario',
#   'crecer',
#   'día',
#   'paciente',
#   'encontrar',
#   'ingresado',
#   'país',
#   'mitad',
#   'corresponder',
#   'cataluña',
#   'andalucío',
#   'madrid',
#   'castilla',
#   'león',
#   'francio',
#   'rusia',
#   'país',
#   'europeo',
#   'contagio',
#   'nivel',
#   'europeo',
#   'españa',
#   'continúar',
#   'tercer',
#   'número',
#   'contagio',
#   'francia',
#   'rusia',
#   'único',
#   'país',
#   'superar',
#   'rusia',
#   'notificar',
#   'cuarto',
#   'quinto',
#   'posición',
#   'encontrar',
#   'reino',
#   'unido',
#   'italia',
#   'positivo',
#   'respectivamente',
#   'reino',
#   'unido',
#   'país',
#   'fallecido',
#   'inicio',
#   'pandemia',
#   'registrar',
#   'italia',
#   'colocar',
#   'detrás',
#   'superar',
#   'día',
#   'corto',
#   'distancia',
#   'francio',
#   'justo',
#   'delante',
#   'españa',
#   'país',
#   'europeo',
#   'contagio',
#   'notificado',
#   'austria',
#   'mantener',
#   'cabeza',
#   'nivel',
#   'desbocado',
#   'positivo',
#   'mejoría',
#   'frente',
#   'dato',
#   'anotado',
#   'obstante',
#   'mejoría',
#   'notorio',
#   'suizo',
#   'caso',
#   'lunes',
#   'país',
#   'sobrepasar',
#   'incidencia',
#   'contagio',
#   'italia',
#   'polonia',
#   'portugal']]

# %%
print(indexer.dictionary)
# Out:
# Dictionary(12362 unique tokens: ['abrir', 'aceptémoslo', 'actitud', 'acuerdo', 'adelgazamiento']...)

# %%
print(indexer.bow)
for doc in indexer.bow:
    print(doc)
    break
# Out:
# <__main__.MyCorpus object at 0x00000282537652B0>
# [(0, 1), (1, 1), (2, 1), (3, 1), (4, 2), (5, 2), (6, 1), (7, 1), (8, 1), (9, 3), (10, 1), (11, 3), (12, 1), (13, 1), (14, 1), (15, 2), (16, 1), (17, 1), (18, 1), (19, 2), (20, 1), (21, 1), (22, 1), (23, 1), (24, 2), (25, 2), (26, 2), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1), (33, 1), (34, 3), (35, 9), (36, 1), (37, 1), (38, 1), (39, 2), (40, 1), (41, 1), (42, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 1), (51, 2), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 2), (59, 3), (60, 1), (61, 1), (62, 2), (63, 1), (64, 1), (65, 2), (66, 1), (67, 1), (68, 1), (69, 1), (70, 1), (71, 1), (72, 2), (73, 3), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 3), (81, 1), (82, 1), (83, 2), (84, 1), (85, 1), (86, 4), (87, 1), (88, 1), (89, 1), (90, 2), (91, 2), (92, 1), (93, 1), (94, 1), (95, 1), (96, 1), (97, 1), (98, 1), (99, 1), (100, 2), (101, 1), (102, 3), (103, 1), (104, 1), (105, 1), (106, 1), (107, 2), (108, 1), (109, 1), (110, 1), (111, 1), (112, 1), (113, 1), (114, 1), (115, 1), (116, 1), (117, 1), (118, 1), (119, 1), (120, 2), (121, 1), (122, 1), (123, 1), (124, 1), (125, 1), (126, 1), (127, 1), (128, 1), (129, 1), (130, 2), (131, 2), (132, 1), (133, 1), (134, 1), (135, 1), (136, 1), (137, 1), (138, 1), (139, 1), (140, 1), (141, 1), (142, 1), (143, 1), (144, 1), (145, 2), (146, 1), (147, 1), (148, 1), (149, 2), (150, 1), (151, 1), (152, 3), (153, 1), (154, 1), (155, 1), (156, 5), (157, 1), (158, 2), (159, 1), (160, 1), (161, 1), (162, 1), (163, 1), (164, 1), (165, 1), (166, 1), (167, 3), (168, 1), (169, 1), (170, 1), (171, 3), (172, 1), (173, 1), (174, 1), (175, 1), (176, 1), (177, 1), (178, 1), (179, 1), (180, 1), (181, 1), (182, 1), (183, 1), (184, 1), (185, 1), (186, 1), (187, 1), (188, 1), (189, 1), (190, 1), (191, 1), (192, 1), (193, 1), (194, 1), (195, 1), (196, 1), (197, 2), (198, 1), (199, 1), (200, 1), (201, 1), (202, 1), (203, 1), (204, 1), (205, 1), (206, 1), (207, 1), (208, 1), (209, 1), (210, 1), (211, 1), (212, 1), (213, 1), (214, 1), (215, 1), (216, 1), (217, 1), (218, 3), (219, 1), (220, 1), (221, 2), (222, 2), (223, 2)]

# %% [markdown]
# # Cálculo de similitudes

# %%
class Searcher():
    
    def __init__(self, indexer):
        self.bow = indexer.bow
        self.dictionary = indexer.dictionary
        self.model = models.TfidfModel(self.bow)
        self.index = Similarity(None, corpus = indexer.bow, num_features = len(indexer.dictionary))
        self.pipeline_eng = LemmatizerTagger("es_dep_news_trf", Tokenizer(SymbolRemover()))
        self.pipeline_esp = LemmatizerTagger("en_core_web_trf", Tokenizer(SymbolRemover()))
        self.traductor = Translator()
        self.documents = indexer.repository
    
    def search(self, lang, query, k = 100, verbose = True):
        """
        En función del lenguaje, ejecuta una pipeline u otra y realiza la búsqueda.
        """
        if lang == "eng":
            pq = self.traductor.translate(self.pipeline_eng.execute(query))
        elif lang == "esp":
            pq = [token["lemma"] for token in self.pipeline_esp.execute(query)]
                        
        vq = self.dictionary.doc2bow(pq)
        qtfidf = self.model[vq]
        sim = self.index[qtfidf]
        ranking = sorted(enumerate(sim), key=itemgetter(1), reverse=True)
        if verbose:
            print(f"Query ==> {pq}")
            for doc, score in ranking[:5]:
                print("[ Score = " + "%.3f" % round(score,3) + " ] " + self.documents[doc][:k])

# %%
searcher = Searcher(indexer)

# %%
searcher.search("eng", "group")
# Out:
# Traduciendo a UNL...
# 	Query original = [{'lemma': 'group', 'pos': 'n'}]
# 	UWs encontradas = ['group(icl>abstraction>thing)', 'group(icl>set>thing)', 'group(icl>unit>thing)']
# Traduciendo a ESP...
# 	UWs = ['group(icl>abstraction>thing)', 'group(icl>set>thing)', 'group(icl>unit>thing)']
# 		UW no encontrada en el diccionario de español: group(icl>set>thing)
# 		UW no encontrada en el diccionario de español: group(icl>unit>thing)
# 	Traducción al español = ['agrupación', 'colectivo']
# Query ==> ['colectivo', 'agrupación']
# [ Score = 0.113 ] Ala Comisión del 8-M ‘se la suda’ el impacto sanitario de las manifestaciones feministas.
#
# A pesar d
# [ Score = 0.046 ] El Real Madrid visita este jueves al CSKA Moscú en el primer partido sin Facundo Campazzo, que se ha
# [ Score = 0.031 ] Unidas Podemos urge a los territorios que utilicen sus competencias para ampliar la regulación de la
# [ Score = 0.027 ] UP, ERC y Bildu buscan mantener viva su enmienda contra los desahucios pese al rechazo del PSOE
# La C
# [ Score = 0.025 ] La presidenta de la Comunidad, Isabel Díaz Ayuso, que se encuentra hoy en Barcelona para reunirse co
